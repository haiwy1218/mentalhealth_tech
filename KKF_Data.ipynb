# %%
import os
import requests
import pandas as pd
import time

# %%
# Make a reference to thecsv file path
csv_path = 'KKF_data.csv'

# Import the books.csv file as a DataFrame
KKF_df = pd.read_csv(csv_path)
KKF_df.head()
# Out:
#   Title: Adults Reporting Mental Illness in the Past Year | KFF  Unnamed: 1  \
# 0                                      United States                  0.190
# 1                                            Alabama                  0.214
# 2                                             Alaska                  0.205
# 3                                            Arizona                  0.192
# 4                                           Arkansas                  0.203
#
#    Unnamed: 2
# 0       0.045
# 1       0.058
# 2       0.054
# 3       0.048
# 4       0.056

# %%
KKF_df = KKF_df.rename({'Unnamed: 1':'Adults Reporting Any Mental Illness in the Past Year', 'Unnamed: 2': 'Adults Reporting Serious Mental Illness in the Past Year'}, axis=1)  # new method
KKF_df.head()
# Out:
#   Title: Adults Reporting Mental Illness in the Past Year | KFF  \
# 0                                      United States
# 1                                            Alabama
# 2                                             Alaska
# 3                                            Arizona
# 4                                           Arkansas
#
#    Adults Reporting Any Mental Illness in the Past Year  \
# 0                                              0.190
# 1                                              0.214
# 2                                              0.205
# 3                                              0.192
# 4                                              0.203
#
#    Adults Reporting Serious Mental Illness in the Past Year
# 0                                              0.045
# 1                                              0.058
# 2                                              0.054
# 3                                              0.048
# 4                                              0.056
