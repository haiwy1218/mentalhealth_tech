# %%
#import Dependencies
import csv
import json
import pandas as pd
import sys, getopt, pprint
from pymongo import MongoClient
import warnings
warnings.filterwarnings('ignore')

# %%
#activating Mongo Client
client = MongoClient('localhost', 27017)

# %%
#adding the client
db = client.db

# %%
#adding the collection
collection= db.collection

# %%
#creating the Data Frame Female and reading the csv
docs=pd.read_csv(r'Female_osmi_data.csv', index_col=0)
docs.head()
# Out:
#         Sex      Location Emp. Coverage  Ranking  \
# Age
# 36   Female      Nebraska           Yes        3
# 39   Female      Nebraska           Yes        3
# 26   Female  Pennsylvania           Yes        3
# 32   Female      New York           Yes        3
# 40   Female      New York           Yes        4
#
#     Do you *currently* have a mental health disorder?
# Age
# 36                                                Yes
# 39                                                Yes
# 26                                                Yes
# 32                                           Possibly
# 40                                                Yes

# %%
#print docs
print(docs)
# Out:
#         Sex      Location Emp. Coverage  Ranking  \
# Age
# 36   Female      Nebraska           Yes        3
# 39   Female      Nebraska           Yes        3
# 26   Female  Pennsylvania           Yes        3
# 32   Female      New York           Yes        3
# 40   Female      New York           Yes        4
# ..      ...           ...           ...      ...
# 42   Female         Texas           Yes        3
# 26   Female           NaN           Yes        2
# 31   Female    California            No        3
# 30   Female           NaN            No        2
# 24   Female        Oregon           Yes        3
#
#     Do you *currently* have a mental health disorder?
# Age
# 36                                                Yes
# 39                                                Yes
# 26                                                Yes
# 32                                           Possibly
# 40                                                Yes
# ...

# %%
#turning it into a dictionary
def csv_to_dict():
    reader = csv.DictReader(open(''/'Female_osmi_data.csv'))
    result = {}
    for row in reader:
        key = row.pop('Sex')
        result[key] = row
    return query

# %%
# create a dictionary 
    Female = {} 
      
    # Open a csv reader called DictReader 
    with open(r'Female_osmi_data.csv', encoding='utf-8') as csvf: 
        csvReader = csv.DictReader(csvf) 
          
        # Convert each row into a dictionary  
        # and add it to data 
        for rows in csvReader: 
              
            # Assuming a column named 'No' to 
            # be the primary key 
            key = rows['Location'] 
            Female[key] = rows

# %%
#printing dictionary
Female
# Out:
# {'Nebraska': OrderedDict([('Age', '19'),
#               ('Sex', 'Female'),
#               ('Location', 'Nebraska'),
#               ('Emp. Coverage', 'Not eligible for coverage / NA'),
#               ('Ranking', '3'),
#               ('Do you *currently* have a mental health disorder?', 'Yes')]),
#  'Pennsylvania': OrderedDict([('Age', '26'),
#               ('Sex', 'Female'),
#               ('Location', 'Pennsylvania'),
#               ('Emp. Coverage', 'Yes'),
#               ('Ranking', '3'),
#               ('Do you *currently* have a mental health disorder?', 'Yes')]),
#  'New York': OrderedDict([('Age', '22'),
#               ('Sex', 'Female'),
#               ('Location', 'New York'),
#               ('Emp. Coverage', 'No'),
#               ('Ranking', '3'),
#               ('Do you *currently* have a mental health disorder?',
#                'Possibly')]),
#  'Wisconsin': OrderedDict([('Age', '45'),
#               ('Sex', 'Female'),
# ...

# %%
# Opening csv file
with open('Female_osmi_data.csv', 'r') as csvfile:
    header = [ "show_id", "Sex"]
    reader = csv.reader(csvfile)

    for row in reader:
        doc={}
        for n in range(0,len(header)):
            doc[header[n]] = row[n]

# %%
#importing CSV
def import_content(filepath):
    collection_name = 'Female' 
    db_cm = mng_db[collection_name]
    cdir = os.path.dirname(__file__)
    file_res = os.path.join(cdir, filepath)

    data = pd.read_csv(file_res)
    data_json = json.loads(data.to_json(orient='Sex'))
    db_cm.remove()
    db_cm.insert(data_json)
    filepath = ''/'Female.csv'  
    import_content(filepath)

# %%
#count of female
docs.count()
# Out:
# Sex                                                  101
# Location                                              68
# Emp. Coverage                                         87
# Ranking                                              101
# Do you *currently* have a mental health disorder?    101
# dtype: int64

# %%
#first 5 in in DataFrame
docs.head()
# Out:
#         Sex      Location Emp. Coverage  Ranking  \
# Age
# 36   Female      Nebraska           Yes        3
# 39   Female      Nebraska           Yes        3
# 26   Female  Pennsylvania           Yes        3
# 32   Female      New York           Yes        3
# 40   Female      New York           Yes        4
#
#     Do you *currently* have a mental health disorder?
# Age
# 36                                                Yes
# 39                                                Yes
# 26                                                Yes
# 32                                           Possibly
# 40                                                Yes

# %%
# Getting shape of the df 
shape = docs.shape 
  
# Printing Number of columns 
print('Number of columns :', shape[1])
# Out:
# Number of columns : 5

# %%
# Getting the list of columns 
col = docs.columns 
  
# Printing Number of columns 
print('Number of columns :', len(col))
# Out:
# Number of columns : 5

# %%
#inforamtion about the DataFrame
docs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 36 to 24
# Data columns (total 5 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Sex                                                101 non-null    object
#  1   Location                                           68 non-null     object
#  2   Emp. Coverage                                      87 non-null     object
#  3   Ranking                                            101 non-null    int64
#  4   Do you *currently* have a mental health disorder?  101 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ KB

# %%
# grouping by hte count of Unnamed one which is Location
docs.groupby(['Location']).count().unstack().fillna(0)
# Out:
#                                                    Location
# Sex                                                California              9
#                                                    Colorado                4
#                                                    District of Columbia    2
#                                                    Florida                 1
#                                                    Georgia                 2
#                                                                           ..
# Do you *currently* have a mental health disorder?  Vermont                 1
#                                                    Virginia                1
#                                                    Washington              7
#                                                    Wisconsin               1
#                                                    Wyoming                 1
# Length: 96, dtype: int64

# %%
#print collection
collection.insert_one(Female)
print(collection.find_one())
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-44-e7c504a7db1f> in <module>
#       1 #print collection
# ----> 2 collection.insert_one(Female)
#       3 print(collection.find_one())
#
# ~\.conda\envs\PythonData\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     699                          write_concern=write_concern,
#     700                          bypass_doc_val=bypass_document_validation,
# --> 701                          session=session),
#     702             write_concern.acknowledged)
#     703
#
# ~\.conda\envs\PythonData\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     613             return self._insert_one(
# ...
