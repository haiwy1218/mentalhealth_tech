# %%
import os
from bs4 import BeautifulSoup as bs
import requests
import pymongo
from splinter import Browser
import pandas as pd
import time 
from pymongo import MongoClient
import csv

# %%
# Make a reference to thecsv file path
csv_path = "MentalHealthCSV.csv"
csv_path2="Male.csv"
csv_path3="Female.csv"

# Import the books.csv file as a DataFrame
MentalHealth_df_c = pd.read_csv(csv_path)
Males = pd.read_csv(csv_path2)
Females = pd.read_csv(csv_path3)
Females= Females.rename(columns={
    "Bad Days Count	": "Bad Days Count",
    "Bad Days Q2	": "Bad Days Q2", 
    
    })

Females.head()
# Out:
#       Sex    Location  Bad Days Count  Bad Days Mean  Bad Days Min  \
# 0  Female     Alabama               1            6.1           6.1
# 1  Female      Alaska               1            4.6           4.6
# 2  Female     Arizona               1            4.9           4.9
# 3  Female    Arkansas               1            6.5           6.5
# 4  Female  California               1            4.2           4.2
#
#    Bad Days Q1  Bad Days Q2  Bad Days Q3  Bad Days Max
# 0          6.1          6.1          6.1           6.1
# 1          4.6          4.6          4.6           4.6
# 2          4.9          4.9          4.9           4.9
# 3          6.5          6.5          6.5           6.5
# 4          4.2          4.2          4.2           4.2

# %%
#Count for rosw missing data 
MentalHealth_df_c.count()
# Out:
# *Are you self-employed?*                                                             352
# How many employees does your company or organization have?                           304
# Is your employer primarily a tech company/organization?                              304
# Is your primary role within your company related to tech/IT?                         304
# Does your employer provide mental health benefits as part of healthcare coverage?    304
#                                                                                     ...
# What country do you *live* in?                                                       352
# What US state or territory do you *live* in?                                         204
# What is your race?                                                                   204
# What country do you *work* in?                                                       352
# What US state or territory do you *work* in?                                         204
# Length: 82, dtype: int64

# %%
MentalHealth_df_c.isna().head()

#all of them
# Out:
#    *Are you self-employed?*  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#    How many employees does your company or organization have?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Is your employer primarily a tech company/organization?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                               True
#
#    If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                               True
#
#    Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    What is your age?  What is your gender?  What country do you *live* in?  \
# 0              False                 False                           False
# 1              False                 False                           False
# 2              False                 False                           False
# 3              False                 False                           False
# 4              False                 False                           False
#
#    What US state or territory do you *live* in?  What is your race?  \
# 0                                         False               False
# 1                                         False               False
# 2                                         False               False
# 3                                         False               False
# 4                                         False               False
#
#    What country do you *work* in?  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
#    What US state or territory do you *work* in?
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
# [5 rows x 82 columns]

# %%
MH_Clean = MentalHealth_df_c.rename(columns={
    "What is your age?": "Age",
    "What is your gender?": "Sex", 
    "What US state or territory do you *live* in?": "Location",
    "Does your employer provide mental health benefits as part of healthcare coverage?": "Emp Coverage",
    "Overall, how well do you think the tech industry supports employees with mental health issues?": "Ranking",
    "Do you *currently* have a mental health disorder?": "Do you *currently* have a mental health disorder?",
    
    })
MH_Clean.head()
# Out:
#    *Are you self-employed?*  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                            100-500
# 4                                             26-100
#
#   Is your employer primarily a tech company/organization?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to tech/IT?  Emp Coverage  \
# 0                                               True            I don't know
# 1                                               True                     Yes
# 2                                               True            I don't know
# 3                                               True            I don't know
# 4                                               True            I don't know
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                       I don't know
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                                Yes
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                          Very easy
# 1                                       I don't know
# 2                                 Somewhat difficult
# 3                                          Very easy
# 4                                       I don't know
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.  \
# 0                                                NaN
# 1                                                NaN
# 2  I think opening up more conversation around th...
# 3                                                NaN
# 4                                                NaN
#
#   If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.  \
# 0                                                NaN
# 1                                                NaN
# 2                                          Thank you
# 3                                                NaN
# 4                                                NaN
#
#   Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   Age   Sex What country do you *live* in?  Location What is your race?  \
# 0  25  Male       United States of America  Nebraska              White
# 1  51  male       United States of America  Nebraska              White
# 2  27  Male       United States of America  Illinois              White
# 3  37  male       United States of America  Nebraska              White
# 4  46     m       United States of America  Nebraska              White
#
#   What country do you *work* in?  What US state or territory do you *work* in?
# 0       United States of America                                      Nebraska
# 1       United States of America                                      Nebraska
# 2       United States of America                                      Illinois
# 3       United States of America                                      Nebraska
# 4       United States of America                                      Nebraska
#
# [5 rows x 82 columns]

# %%
#Need Columns only 
MentalHealthClean2 = MH_Clean[["Age", "Sex", "Location", "Emp Coverage","Ranking", "Do you *currently* have a mental health disorder?"]]
print(MentalHealthClean2)
# Out:
#      Age           Sex   Location  Emp Coverage  Ranking  \
# 0     25          Male   Nebraska  I don't know        4
# 1     51          male   Nebraska           Yes        1
# 2     27          Male   Illinois  I don't know        2
# 3     37          male   Nebraska  I don't know        3
# 4     46             m   Nebraska  I don't know        3
# ..   ...           ...        ...           ...      ...
# 347   27          male        NaN  I don't know        3
# 348   48             m  Louisiana           NaN        3
# 349   50             M        NaN           NaN        5
# 350   30        female        NaN            No        2
# 351   24  Female (cis)     Oregon           Yes        3
#
#     Do you *currently* have a mental health disorder?
# 0                                          Don't Know
# 1                                            Possibly
# 2                                                  No
# 3                                                  No
# 4                                                  No
# ..                                                ...
# 347                                          Possibly
# 348                                                No
# 349                                                No
# 350                                          Possibly
# 351                                               Yes
#
# [352 rows x 6 columns]

# %%
# Unique labels 
MentalHealthClean2['Sex'].unique()
# Out:
# array(['Male', 'male', 'm', 'female', 'Female', nan, 'M', 'F', 'f',
#        'Let\'s keep it simple and say "male"', 'Non-binary',
#        'Identify as male', 'Male ', 'Woman', 'Non binary', 'Masculine',
#        'Cishet male', 'None', 'Female-identified', 'woman', 'Nonbinary',
#        'agender', 'Man', 'Questioning', 'cis male', 'Cis Male',
#        'I have a penis', 'rr', 'cis woman', 'Agender trans woman',
#        'Female ', 'femmina', '43', 'Trans man', 'man', 'masculino',
#        'I am a Wookie', 'Make', 'Trans non-binary/genderfluid',
#        'CIS Male', 'Non-binary and gender fluid', 'Femile',
#        'Female (cis)'], dtype=object)

# %%
#Change male leaning
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['m'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['M'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Let\'s keep it simple and say "male"'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Masculine'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cishet male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Man'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['cis male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Trans Man'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['I have a penis'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['man'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['masculino'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['CIS Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cis Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cis Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cis Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Male '],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Trans man'],'Male')
# Out:
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Change female leaning
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['f'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['F'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Female-identified'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Agender trans woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Female (cis)'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Femile'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['femmina'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['female'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['cis woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Female '],'Female')
# Out:
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/megancross/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
MentalHealthClean2['Sex'].unique()
# Out:
# array(['Male', 'Female', nan, 'Non-binary', 'Identify as male',
#        'Non binary', 'None', 'Nonbinary', 'agender', 'Questioning', 'rr',
#        '43', 'I am a Wookie', 'Make', 'Trans non-binary/genderfluid',
#        'Non-binary and gender fluid'], dtype=object)

# %%
# Number by gender
MentalHealthClean2['Sex']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 347      Male
# 348      Male
# 349      Male
# 350    Female
# 351    Female
# Name: Sex, Length: 352, dtype: object

# %%
#Dropping other labels 
L= ['Non-binary', 'Non binary', 'None',
       'Nonbinary', 'agender', 'Questioning', 'rr', '43', 'I am a Wookie',
       'Make', 'Trans non-binary/genderfluid',
       'Non-binary and gender fluid']

print (MentalHealthClean2[~MentalHealthClean2.Sex.isin(L)])
MentalHealthClean2.head()
# Out:
#      Age     Sex   Location  Emp Coverage  Ranking  \
# 0     25    Male   Nebraska  I don't know        4
# 1     51    Male   Nebraska           Yes        1
# 2     27    Male   Illinois  I don't know        2
# 3     37    Male   Nebraska  I don't know        3
# 4     46    Male   Nebraska  I don't know        3
# ..   ...     ...        ...           ...      ...
# 347   27    Male        NaN  I don't know        3
# 348   48    Male  Louisiana           NaN        3
# 349   50    Male        NaN           NaN        5
# 350   30  Female        NaN            No        2
# 351   24  Female     Oregon           Yes        3
#
#     Do you *currently* have a mental health disorder?
# 0                                          Don't Know
# 1                                            Possibly
# 2                                                  No
# 3                                                  No
# 4                                                  No
# ..                                                ...
# 347                                          Possibly
# 348                                                No
# 349                                                No
# 350                                          Possibly
# 351                                               Yes
#
# [337 rows x 6 columns]
#    Age   Sex  Location  Emp Coverage  Ranking  \
# 0   25  Male  Nebraska  I don't know        4
# 1   51  Male  Nebraska           Yes        1
# 2   27  Male  Illinois  I don't know        2
# 3   37  Male  Nebraska  I don't know        3
# 4   46  Male  Nebraska  I don't know        3
#
#   Do you *currently* have a mental health disorder?
# 0                                        Don't Know
# 1                                          Possibly
# 2                                                No
# 3                                                No
# 4                                                No

# %%
output_data_file = "MentalH.csv"

# %%
#split data frame by sex
# This is so that we can join by location more easily
#NaN were not removed from the osmi data set because ever row contained at least one NaN

Female_osmi_data =MentalHealthClean2 [MentalHealthClean2['Sex'] == 'Female'] 
Male_osmi_data=MentalHealthClean2[MentalHealthClean2['Sex'] == 'Male']

# %%
#check dataframe 

Female_osmi_data.head()
Male_osmi_data.head()
# Out:
#    Age   Sex  Location  Emp Coverage  Ranking  \
# 0   25  Male  Nebraska  I don't know        4
# 1   51  Male  Nebraska           Yes        1
# 2   27  Male  Illinois  I don't know        2
# 3   37  Male  Nebraska  I don't know        3
# 4   46  Male  Nebraska  I don't know        3
#
#   Do you *currently* have a mental health disorder?
# 0                                        Don't Know
# 1                                          Possibly
# 2                                                No
# 3                                                No
# 4                                                No

# %%
#save split datasets
Female_osmi_data.to_csv('Female_osmi_data.csv', index = False, header=True)
Male_osmi_data.to_csv('Male_osmi_data.csv', index = False, header=True)

# %%
#Join male data sets and female datasets
males_merge= pd.merge(Male_osmi_data, Males, on='Location')
males_merge=males_merge.drop(columns=["Sex_y"])


Females_merge= pd.merge(Female_osmi_data, Females, on='Location')
Females_merge=Females_merge.drop(columns=["Sex_y"])

Females_merge.head()
# Out:
#    Age   Sex_x      Location                    Emp Coverage  Ranking  \
# 0   36  Female      Nebraska                             Yes        3
# 1   39  Female      Nebraska                             Yes        3
# 2   20  Female      Nebraska                             Yes        2
# 3   19  Female      Nebraska  Not eligible for coverage / NA        3
# 4   26  Female  Pennsylvania                             Yes        3
#
#   Do you *currently* have a mental health disorder?  Bad Days Count  \
# 0                                               Yes               1
# 1                                               Yes               1
# 2                                               Yes               1
# 3                                               Yes               1
# 4                                               Yes               1
#
#    Bad Days Mean  Bad Days Min  Bad Days Q1  Bad Days Q2  Bad Days Q3  \
# 0            4.5           4.5          4.5          4.5          4.5
# 1            4.5           4.5          4.5          4.5          4.5
# 2            4.5           4.5          4.5          4.5          4.5
# 3            4.5           4.5          4.5          4.5          4.5
# 4            5.2           5.2          5.2          5.2          5.2
#
#    Bad Days Max
# 0           4.5
# 1           4.5
# 2           4.5
# 3           4.5
# 4           5.2

# %%
#making the master sheet by cocatinating the tow joins. This will add the sheets together without dropping any rows
Master_sheet= pd.concat([Females_merge, males_merge], ignore_index=True)
Master_sheet.head(100)
# Out:
#     Age   Sex_x        Location                    Emp Coverage  Ranking  \
# 0    36  Female        Nebraska                             Yes        3
# 1    39  Female        Nebraska                             Yes        3
# 2    20  Female        Nebraska                             Yes        2
# 3    19  Female        Nebraska  Not eligible for coverage / NA        3
# 4    26  Female    Pennsylvania                             Yes        3
# ..  ...     ...             ...                             ...      ...
# 95   63    Male         Georgia                             Yes        3
# 96   35    Male  North Carolina                             Yes        2
# 97   35    Male  North Carolina                             NaN        2
# 98   30    Male  North Carolina                    I don't know        3
# 99   45    Male  North Carolina  Not eligible for coverage / NA        1
#
#    Do you *currently* have a mental health disorder?  Bad Days Count  \
# 0                                                Yes               1
# 1                                                Yes               1
# 2                                                Yes               1
# 3                                                Yes               1
# 4                                                Yes               1
# ..                                               ...             ...
# 95                                                No               1
# 96                                          Possibly               1
# 97                                          Possibly               1
# 98                                                No               1
# 99                                               Yes               1
#
#     Bad Days Mean  Bad Days Min  Bad Days Q1  Bad Days Q2  Bad Days Q3  \
# 0             4.5           4.5          4.5          4.5          4.5
# 1             4.5           4.5          4.5          4.5          4.5
# 2             4.5           4.5          4.5          4.5          4.5
# 3             4.5           4.5          4.5          4.5          4.5
# 4             5.2           5.2          5.2          5.2          5.2
# ..            ...           ...          ...          ...          ...
# 95            4.3           4.3          4.3          4.3          4.3
# 96            3.6           3.6          3.6          3.6          3.6
# 97            3.6           3.6          3.6          3.6          3.6
# 98            3.6           3.6          3.6          3.6          3.6
# 99            3.6           3.6          3.6          3.6          3.6
#
#     Bad Days Max
# 0            4.5
# 1            4.5
# 2            4.5
# 3            4.5
# 4            5.2
# ..           ...
# 95           4.3
# 96           3.6
# 97           3.6
# 98           3.6
# 99           3.6
#
# [100 rows x 13 columns]

# %%
#wrirte master to csv
Master_sheet.to_csv('Master_sheet.csv', index = False, header=True)

# %%
MH_Clean['Do you *currently* have a mental health disorder?'].unique()
# Out:
# array(["Don't Know", 'Possibly', 'No', 'Yes'], dtype=object)

# %%
# Make a reference to thecsv file path
csv_path = "Master_sheet.csv"

# Import the books.csv file as a DataFrame
test_df = pd.read_csv(csv_path)
test_df.count()
# Out:
# Age                                                  193
# Sex_x                                                193
# Location                                             193
# Emp Coverage                                         174
# Ranking                                              193
# Do you *currently* have a mental health disorder?    193
# Bad Days Count                                       193
# Bad Days Mean                                        193
# Bad Days Min                                         193
# Bad Days Q1                                          193
# Bad Days Q2                                          193
# Bad Days Q3                                          193
# Bad Days Max                                         193
# dtype: int64

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
mentalhealth_db = client.master_table

master_table = mentalhealth_db.master_table

# %%
# MentalHealthClean2.reset_index(inplace=True)
data_dict = Master_sheet.to_dict("records")
# Insert collection
master_table.insert_many(data_dict)

# %%
results = master_table.find()
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('5fc5a32afe891ca45942214c'), 'Age': 36, 'Sex_x': 'Female', 'Location': 'Nebraska', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.5, 'Bad Days Min': 4.5, 'Bad Days Q1': 4.5, 'Bad Days Q2': 4.5, 'Bad Days Q3': 4.5, 'Bad Days Max': 4.5}
# {'_id': ObjectId('5fc5a32afe891ca45942214d'), 'Age': 39, 'Sex_x': 'Female', 'Location': 'Nebraska', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.5, 'Bad Days Min': 4.5, 'Bad Days Q1': 4.5, 'Bad Days Q2': 4.5, 'Bad Days Q3': 4.5, 'Bad Days Max': 4.5}
# {'_id': ObjectId('5fc5a32afe891ca45942214e'), 'Age': 20, 'Sex_x': 'Female', 'Location': 'Nebraska', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.5, 'Bad Days Min': 4.5, 'Bad Days Q1': 4.5, 'Bad Days Q2': 4.5, 'Bad Days Q3': 4.5, 'Bad Days Max': 4.5}
# {'_id': ObjectId('5fc5a32afe891ca45942214f'), 'Age': 19, 'Sex_x': 'Female', 'Location': 'Nebraska', 'Emp Coverage': 'Not eligible for coverage / NA', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.5, 'Bad Days Min': 4.5, 'Bad Days Q1': 4.5, 'Bad Days Q2': 4.5, 'Bad Days Q3': 4.5, 'Bad Days Max': 4.5}
# {'_id': ObjectId('5fc5a32afe891ca459422150'), 'Age': 26, 'Sex_x': 'Female', 'Location': 'Pennsylvania', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.2, 'Bad Days Min': 5.2, 'Bad Days Q1': 5.2, 'Bad Days Q2': 5.2, 'Bad Days Q3': 5.2, 'Bad Days Max': 5.2}
# {'_id': ObjectId('5fc5a32afe891ca459422151'), 'Age': 32, 'Sex_x': 'Female', 'Location': 'New York', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca459422152'), 'Age': 40, 'Sex_x': 'Female', 'Location': 'New York', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca459422153'), 'Age': 26, 'Sex_x': 'Female', 'Location': 'New York', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca459422154'), 'Age': 28, 'Sex_x': 'Female', 'Location': 'New York', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': "Don't Know", 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca459422155'), 'Age': 36, 'Sex_x': 'Female', 'Location': 'New York', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca459422156'), 'Age': 36, 'Sex_x': 'Female', 'Location': 'New York', 'Emp Coverage': nan, 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca459422157'), 'Age': 22, 'Sex_x': 'Female', 'Location': 'New York', 'Emp Coverage': 'No', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca459422158'), 'Age': 45, 'Sex_x': 'Female', 'Location': 'Wisconsin', 'Emp Coverage': "I don't know", 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.6, 'Bad Days Min': 4.6, 'Bad Days Q1': 4.6, 'Bad Days Q2': 4.6, 'Bad Days Q3': 4.6, 'Bad Days Max': 4.6}
# {'_id': ObjectId('5fc5a32afe891ca459422159'), 'Age': 24, 'Sex_x': 'Female', 'Location': 'Massachusetts', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.7, 'Bad Days Min': 4.7, 'Bad Days Q1': 4.7, 'Bad Days Q2': 4.7, 'Bad Days Q3': 4.7, 'Bad Days Max': 4.7}
# {'_id': ObjectId('5fc5a32afe891ca45942215a'), 'Age': 34, 'Sex_x': 'Female', 'Location': 'Massachusetts', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.7, 'Bad Days Min': 4.7, 'Bad Days Q1': 4.7, 'Bad Days Q2': 4.7, 'Bad Days Q3': 4.7, 'Bad Days Max': 4.7}
# {'_id': ObjectId('5fc5a32afe891ca45942215b'), 'Age': 53, 'Sex_x': 'Female', 'Location': 'Minnesota', 'Emp Coverage': nan, 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.4, 'Bad Days Min': 4.4, 'Bad Days Q1': 4.4, 'Bad Days Q2': 4.4, 'Bad Days Q3': 4.4, 'Bad Days Max': 4.4}
# {'_id': ObjectId('5fc5a32afe891ca45942215c'), 'Age': 34, 'Sex_x': 'Female', 'Location': 'Minnesota', 'Emp Coverage': nan, 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.4, 'Bad Days Min': 4.4, 'Bad Days Q1': 4.4, 'Bad Days Q2': 4.4, 'Bad Days Q3': 4.4, 'Bad Days Max': 4.4}
# {'_id': ObjectId('5fc5a32afe891ca45942215d'), 'Age': 31, 'Sex_x': 'Female', 'Location': 'Minnesota', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.4, 'Bad Days Min': 4.4, 'Bad Days Q1': 4.4, 'Bad Days Q2': 4.4, 'Bad Days Q3': 4.4, 'Bad Days Max': 4.4}
# {'_id': ObjectId('5fc5a32afe891ca45942215e'), 'Age': 53, 'Sex_x': 'Female', 'Location': 'Wyoming', 'Emp Coverage': "I don't know", 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.7, 'Bad Days Min': 4.7, 'Bad Days Q1': 4.7, 'Bad Days Q2': 4.7, 'Bad Days Q3': 4.7, 'Bad Days Max': 4.7}
# {'_id': ObjectId('5fc5a32afe891ca45942215f'), 'Age': 34, 'Sex_x': 'Female', 'Location': 'Colorado', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.4, 'Bad Days Min': 4.4, 'Bad Days Q1': 4.4, 'Bad Days Q2': 4.4, 'Bad Days Q3': 4.4, 'Bad Days Max': 4.4}
# {'_id': ObjectId('5fc5a32afe891ca459422160'), 'Age': 28, 'Sex_x': 'Female', 'Location': 'Colorado', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.4, 'Bad Days Min': 4.4, 'Bad Days Q1': 4.4, 'Bad Days Q2': 4.4, 'Bad Days Q3': 4.4, 'Bad Days Max': 4.4}
# {'_id': ObjectId('5fc5a32afe891ca459422161'), 'Age': 24, 'Sex_x': 'Female', 'Location': 'Colorado', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.4, 'Bad Days Min': 4.4, 'Bad Days Q1': 4.4, 'Bad Days Q2': 4.4, 'Bad Days Q3': 4.4, 'Bad Days Max': 4.4}
# {'_id': ObjectId('5fc5a32afe891ca459422162'), 'Age': 26, 'Sex_x': 'Female', 'Location': 'Colorado', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.4, 'Bad Days Min': 4.4, 'Bad Days Q1': 4.4, 'Bad Days Q2': 4.4, 'Bad Days Q3': 4.4, 'Bad Days Max': 4.4}
# {'_id': ObjectId('5fc5a32afe891ca459422163'), 'Age': 32, 'Sex_x': 'Female', 'Location': 'Michigan', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.8, 'Bad Days Min': 5.8, 'Bad Days Q1': 5.8, 'Bad Days Q2': 5.8, 'Bad Days Q3': 5.8, 'Bad Days Max': 5.8}
# {'_id': ObjectId('5fc5a32afe891ca459422164'), 'Age': 26, 'Sex_x': 'Female', 'Location': 'Michigan', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.8, 'Bad Days Min': 5.8, 'Bad Days Q1': 5.8, 'Bad Days Q2': 5.8, 'Bad Days Q3': 5.8, 'Bad Days Max': 5.8}
# {'_id': ObjectId('5fc5a32afe891ca459422165'), 'Age': 25, 'Sex_x': 'Female', 'Location': 'Michigan', 'Emp Coverage': 'Not eligible for coverage / NA', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.8, 'Bad Days Min': 5.8, 'Bad Days Q1': 5.8, 'Bad Days Q2': 5.8, 'Bad Days Q3': 5.8, 'Bad Days Max': 5.8}
# {'_id': ObjectId('5fc5a32afe891ca459422166'), 'Age': 32, 'Sex_x': 'Female', 'Location': 'North Carolina', 'Emp Coverage': 'No', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': "Don't Know", 'Bad Days Count': 1, 'Bad Days Mean': 4.9, 'Bad Days Min': 4.9, 'Bad Days Q1': 4.9, 'Bad Days Q2': 4.9, 'Bad Days Q3': 4.9, 'Bad Days Max': 4.9}
# {'_id': ObjectId('5fc5a32afe891ca459422167'), 'Age': 47, 'Sex_x': 'Female', 'Location': 'North Carolina', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.9, 'Bad Days Min': 4.9, 'Bad Days Q1': 4.9, 'Bad Days Q2': 4.9, 'Bad Days Q3': 4.9, 'Bad Days Max': 4.9}
# {'_id': ObjectId('5fc5a32afe891ca459422168'), 'Age': 31, 'Sex_x': 'Female', 'Location': 'California', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca459422169'), 'Age': 34, 'Sex_x': 'Female', 'Location': 'California', 'Emp Coverage': nan, 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca45942216a'), 'Age': 22, 'Sex_x': 'Female', 'Location': 'California', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca45942216b'), 'Age': 59, 'Sex_x': 'Female', 'Location': 'California', 'Emp Coverage': nan, 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca45942216c'), 'Age': 29, 'Sex_x': 'Female', 'Location': 'California', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca45942216d'), 'Age': 27, 'Sex_x': 'Female', 'Location': 'California', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca45942216e'), 'Age': 30, 'Sex_x': 'Female', 'Location': 'California', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca45942216f'), 'Age': 42, 'Sex_x': 'Female', 'Location': 'California', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca459422170'), 'Age': 31, 'Sex_x': 'Female', 'Location': 'California', 'Emp Coverage': 'No', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.2, 'Bad Days Min': 4.2, 'Bad Days Q1': 4.2, 'Bad Days Q2': 4.2, 'Bad Days Q3': 4.2, 'Bad Days Max': 4.2}
# {'_id': ObjectId('5fc5a32afe891ca459422171'), 'Age': 45, 'Sex_x': 'Female', 'Location': 'Vermont', 'Emp Coverage': "I don't know", 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.9, 'Bad Days Min': 4.9, 'Bad Days Q1': 4.9, 'Bad Days Q2': 4.9, 'Bad Days Q3': 4.9, 'Bad Days Max': 4.9}
# {'_id': ObjectId('5fc5a32afe891ca459422172'), 'Age': 27, 'Sex_x': 'Female', 'Location': 'Indiana', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 5.6, 'Bad Days Min': 5.6, 'Bad Days Q1': 5.6, 'Bad Days Q2': 5.6, 'Bad Days Q3': 5.6, 'Bad Days Max': 5.6}
# {'_id': ObjectId('5fc5a32afe891ca459422173'), 'Age': 24, 'Sex_x': 'Female', 'Location': 'Georgia', 'Emp Coverage': nan, 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.2, 'Bad Days Min': 5.2, 'Bad Days Q1': 5.2, 'Bad Days Q2': 5.2, 'Bad Days Q3': 5.2, 'Bad Days Max': 5.2}
# {'_id': ObjectId('5fc5a32afe891ca459422174'), 'Age': 27, 'Sex_x': 'Female', 'Location': 'Georgia', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.2, 'Bad Days Min': 5.2, 'Bad Days Q1': 5.2, 'Bad Days Q2': 5.2, 'Bad Days Q3': 5.2, 'Bad Days Max': 5.2}
# {'_id': ObjectId('5fc5a32afe891ca459422175'), 'Age': 33, 'Sex_x': 'Female', 'Location': 'Oregon', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca459422176'), 'Age': 39, 'Sex_x': 'Female', 'Location': 'Oregon', 'Emp Coverage': "I don't know", 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca459422177'), 'Age': 35, 'Sex_x': 'Female', 'Location': 'Oregon', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca459422178'), 'Age': 28, 'Sex_x': 'Female', 'Location': 'Oregon', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca459422179'), 'Age': 24, 'Sex_x': 'Female', 'Location': 'Oregon', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca45942217a'), 'Age': 53, 'Sex_x': 'Female', 'Location': 'Washington', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca45942217b'), 'Age': 25, 'Sex_x': 'Female', 'Location': 'Washington', 'Emp Coverage': 'Not eligible for coverage / NA', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca45942217c'), 'Age': 28, 'Sex_x': 'Female', 'Location': 'Washington', 'Emp Coverage': 'No', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca45942217d'), 'Age': 26, 'Sex_x': 'Female', 'Location': 'Washington', 'Emp Coverage': "I don't know", 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca45942217e'), 'Age': 32, 'Sex_x': 'Female', 'Location': 'Washington', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca45942217f'), 'Age': 43, 'Sex_x': 'Female', 'Location': 'Washington', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca459422180'), 'Age': 30, 'Sex_x': 'Female', 'Location': 'Washington', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.1, 'Bad Days Min': 5.1, 'Bad Days Q1': 5.1, 'Bad Days Q2': 5.1, 'Bad Days Q3': 5.1, 'Bad Days Max': 5.1}
# {'_id': ObjectId('5fc5a32afe891ca459422181'), 'Age': 54, 'Sex_x': 'Female', 'Location': 'Illinois', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.6, 'Bad Days Min': 4.6, 'Bad Days Q1': 4.6, 'Bad Days Q2': 4.6, 'Bad Days Q3': 4.6, 'Bad Days Max': 4.6}
# {'_id': ObjectId('5fc5a32afe891ca459422182'), 'Age': 38, 'Sex_x': 'Female', 'Location': 'Illinois', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.6, 'Bad Days Min': 4.6, 'Bad Days Q1': 4.6, 'Bad Days Q2': 4.6, 'Bad Days Q3': 4.6, 'Bad Days Max': 4.6}
# {'_id': ObjectId('5fc5a32afe891ca459422183'), 'Age': 30, 'Sex_x': 'Female', 'Location': 'Illinois', 'Emp Coverage': nan, 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.6, 'Bad Days Min': 4.6, 'Bad Days Q1': 4.6, 'Bad Days Q2': 4.6, 'Bad Days Q3': 4.6, 'Bad Days Max': 4.6}
# {'_id': ObjectId('5fc5a32afe891ca459422184'), 'Age': 30, 'Sex_x': 'Female', 'Location': 'Illinois', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.6, 'Bad Days Min': 4.6, 'Bad Days Q1': 4.6, 'Bad Days Q2': 4.6, 'Bad Days Q3': 4.6, 'Bad Days Max': 4.6}
# {'_id': ObjectId('5fc5a32afe891ca459422185'), 'Age': 49, 'Sex_x': 'Female', 'Location': 'Ohio', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.6, 'Bad Days Min': 5.6, 'Bad Days Q1': 5.6, 'Bad Days Q2': 5.6, 'Bad Days Q3': 5.6, 'Bad Days Max': 5.6}
# {'_id': ObjectId('5fc5a32afe891ca459422186'), 'Age': 29, 'Sex_x': 'Female', 'Location': 'Maryland', 'Emp Coverage': "I don't know", 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a32afe891ca459422187'), 'Age': 44, 'Sex_x': 'Female', 'Location': 'Maryland', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a32afe891ca459422188'), 'Age': 24, 'Sex_x': 'Female', 'Location': 'Maryland', 'Emp Coverage': 'Not eligible for coverage / NA', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a32afe891ca459422189'), 'Age': 37, 'Sex_x': 'Female', 'Location': 'District of Columbia', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.8, 'Bad Days Min': 4.8, 'Bad Days Q1': 4.8, 'Bad Days Q2': 4.8, 'Bad Days Q3': 4.8, 'Bad Days Max': 4.8}
# {'_id': ObjectId('5fc5a32afe891ca45942218a'), 'Age': 28, 'Sex_x': 'Female', 'Location': 'District of Columbia', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.8, 'Bad Days Min': 4.8, 'Bad Days Q1': 4.8, 'Bad Days Q2': 4.8, 'Bad Days Q3': 4.8, 'Bad Days Max': 4.8}
# {'_id': ObjectId('5fc5a32afe891ca45942218b'), 'Age': 38, 'Sex_x': 'Female', 'Location': 'Texas', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.5, 'Bad Days Min': 4.5, 'Bad Days Q1': 4.5, 'Bad Days Q2': 4.5, 'Bad Days Q3': 4.5, 'Bad Days Max': 4.5}
# {'_id': ObjectId('5fc5a32afe891ca45942218c'), 'Age': 42, 'Sex_x': 'Female', 'Location': 'Texas', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.5, 'Bad Days Min': 4.5, 'Bad Days Q1': 4.5, 'Bad Days Q2': 4.5, 'Bad Days Q3': 4.5, 'Bad Days Max': 4.5}
# {'_id': ObjectId('5fc5a32afe891ca45942218d'), 'Age': 51, 'Sex_x': 'Female', 'Location': 'Florida', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 5.0, 'Bad Days Min': 5.0, 'Bad Days Q1': 5.0, 'Bad Days Q2': 5.0, 'Bad Days Q3': 5.0, 'Bad Days Max': 5.0}
# {'_id': ObjectId('5fc5a32afe891ca45942218e'), 'Age': 26, 'Sex_x': 'Female', 'Location': 'Virginia', 'Emp Coverage': 'No', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.6, 'Bad Days Min': 4.6, 'Bad Days Q1': 4.6, 'Bad Days Q2': 4.6, 'Bad Days Q3': 4.6, 'Bad Days Max': 4.6}
# {'_id': ObjectId('5fc5a32afe891ca45942218f'), 'Age': 38, 'Sex_x': 'Female', 'Location': 'Idaho', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.9, 'Bad Days Min': 4.9, 'Bad Days Q1': 4.9, 'Bad Days Q2': 4.9, 'Bad Days Q3': 4.9, 'Bad Days Max': 4.9}
# {'_id': ObjectId('5fc5a32afe891ca459422190'), 'Age': 25, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': "I don't know", 'Ranking': 4, 'Do you *currently* have a mental health disorder?': "Don't Know", 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca459422191'), 'Age': 51, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca459422192'), 'Age': 37, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca459422193'), 'Age': 46, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca459422194'), 'Age': 42, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca459422195'), 'Age': 32, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': "I don't know", 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca459422196'), 'Age': 0, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': "I don't know", 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca459422197'), 'Age': 38, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca459422198'), 'Age': 31, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca459422199'), 'Age': 30, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca45942219a'), 'Age': 38, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca45942219b'), 'Age': 34, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca45942219c'), 'Age': 39, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca45942219d'), 'Age': 50, 'Sex_x': 'Male', 'Location': 'Nebraska', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 2.9, 'Bad Days Min': 2.9, 'Bad Days Q1': 2.9, 'Bad Days Q2': 2.9, 'Bad Days Q3': 2.9, 'Bad Days Max': 2.9}
# {'_id': ObjectId('5fc5a32afe891ca45942219e'), 'Age': 27, 'Sex_x': 'Male', 'Location': 'Illinois', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a32afe891ca45942219f'), 'Age': 58, 'Sex_x': 'Male', 'Location': 'Illinois', 'Emp Coverage': nan, 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a32afe891ca4594221a0'), 'Age': 36, 'Sex_x': 'Male', 'Location': 'Illinois', 'Emp Coverage': nan, 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a32afe891ca4594221a1'), 'Age': 42, 'Sex_x': 'Male', 'Location': 'Illinois', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a32afe891ca4594221a2'), 'Age': 38, 'Sex_x': 'Male', 'Location': 'Illinois', 'Emp Coverage': nan, 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a32afe891ca4594221a3'), 'Age': 32, 'Sex_x': 'Male', 'Location': 'Illinois', 'Emp Coverage': nan, 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a32afe891ca4594221a4'), 'Age': 30, 'Sex_x': 'Male', 'Location': 'Illinois', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a32afe891ca4594221a5'), 'Age': 27, 'Sex_x': 'Male', 'Location': 'Illinois', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': "Don't Know", 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a32afe891ca4594221a6'), 'Age': 35, 'Sex_x': 'Male', 'Location': 'Wisconsin', 'Emp Coverage': nan, 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.8, 'Bad Days Min': 3.8, 'Bad Days Q1': 3.8, 'Bad Days Q2': 3.8, 'Bad Days Q3': 3.8, 'Bad Days Max': 3.8}
# {'_id': ObjectId('5fc5a32afe891ca4594221a7'), 'Age': 37, 'Sex_x': 'Male', 'Location': 'Wisconsin', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.8, 'Bad Days Min': 3.8, 'Bad Days Q1': 3.8, 'Bad Days Q2': 3.8, 'Bad Days Q3': 3.8, 'Bad Days Max': 3.8}
# {'_id': ObjectId('5fc5a32afe891ca4594221a8'), 'Age': 31, 'Sex_x': 'Male', 'Location': 'Connecticut', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221a9'), 'Age': 37, 'Sex_x': 'Male', 'Location': 'Georgia', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a32afe891ca4594221aa'), 'Age': 30, 'Sex_x': 'Male', 'Location': 'Georgia', 'Emp Coverage': "I don't know", 'Ranking': 5, 'Do you *currently* have a mental health disorder?': "Don't Know", 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a32afe891ca4594221ab'), 'Age': 63, 'Sex_x': 'Male', 'Location': 'Georgia', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a32afe891ca4594221ac'), 'Age': 35, 'Sex_x': 'Male', 'Location': 'North Carolina', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221ad'), 'Age': 35, 'Sex_x': 'Male', 'Location': 'North Carolina', 'Emp Coverage': nan, 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221ae'), 'Age': 30, 'Sex_x': 'Male', 'Location': 'North Carolina', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221af'), 'Age': 45, 'Sex_x': 'Male', 'Location': 'North Carolina', 'Emp Coverage': 'Not eligible for coverage / NA', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221b0'), 'Age': 56, 'Sex_x': 'Male', 'Location': 'North Carolina', 'Emp Coverage': nan, 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221b1'), 'Age': 41, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221b2'), 'Age': 29, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': "I don't know", 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221b3'), 'Age': 27, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221b4'), 'Age': 34, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': "I don't know", 'Ranking': 4, 'Do you *currently* have a mental health disorder?': "Don't Know", 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221b5'), 'Age': 27, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': "I don't know", 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221b6'), 'Age': 50, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221b7'), 'Age': 52, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221b8'), 'Age': 34, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221b9'), 'Age': 30, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221ba'), 'Age': 40, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221bb'), 'Age': 38, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221bc'), 'Age': 33, 'Sex_x': 'Male', 'Location': 'Tennessee', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a32afe891ca4594221bd'), 'Age': 37, 'Sex_x': 'Male', 'Location': 'New York', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221be'), 'Age': 37, 'Sex_x': 'Male', 'Location': 'New York', 'Emp Coverage': "I don't know", 'Ranking': 5, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221bf'), 'Age': 31, 'Sex_x': 'Male', 'Location': 'New York', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221c0'), 'Age': 37, 'Sex_x': 'Male', 'Location': 'New York', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221c1'), 'Age': 32, 'Sex_x': 'Male', 'Location': 'New York', 'Emp Coverage': "I don't know", 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221c2'), 'Age': 36, 'Sex_x': 'Male', 'Location': 'New York', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221c3'), 'Age': 35, 'Sex_x': 'Male', 'Location': 'New York', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221c4'), 'Age': 46, 'Sex_x': 'Male', 'Location': 'New York', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221c5'), 'Age': 53, 'Sex_x': 'Male', 'Location': 'Oregon', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221c6'), 'Age': 28, 'Sex_x': 'Male', 'Location': 'Colorado', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221c7'), 'Age': 35, 'Sex_x': 'Male', 'Location': 'Colorado', 'Emp Coverage': 'No', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221c8'), 'Age': 28, 'Sex_x': 'Male', 'Location': 'Colorado', 'Emp Coverage': "I don't know", 'Ranking': 4, 'Do you *currently* have a mental health disorder?': "Don't Know", 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221c9'), 'Age': 50, 'Sex_x': 'Male', 'Location': 'Colorado', 'Emp Coverage': nan, 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221ca'), 'Age': 55, 'Sex_x': 'Male', 'Location': 'Colorado', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221cb'), 'Age': 32, 'Sex_x': 'Male', 'Location': 'Colorado', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221cc'), 'Age': 45, 'Sex_x': 'Male', 'Location': 'Colorado', 'Emp Coverage': 'No', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221cd'), 'Age': 37, 'Sex_x': 'Male', 'Location': 'Colorado', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221ce'), 'Age': 42, 'Sex_x': 'Male', 'Location': 'Colorado', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221cf'), 'Age': 27, 'Sex_x': 'Male', 'Location': 'Colorado', 'Emp Coverage': nan, 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a32afe891ca4594221d0'), 'Age': 42, 'Sex_x': 'Male', 'Location': 'Florida', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.7, 'Bad Days Min': 3.7, 'Bad Days Q1': 3.7, 'Bad Days Q2': 3.7, 'Bad Days Q3': 3.7, 'Bad Days Max': 3.7}
# {'_id': ObjectId('5fc5a32afe891ca4594221d1'), 'Age': 42, 'Sex_x': 'Male', 'Location': 'Florida', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.7, 'Bad Days Min': 3.7, 'Bad Days Q1': 3.7, 'Bad Days Q2': 3.7, 'Bad Days Q3': 3.7, 'Bad Days Max': 3.7}
# {'_id': ObjectId('5fc5a32afe891ca4594221d2'), 'Age': 41, 'Sex_x': 'Male', 'Location': 'California', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221d3'), 'Age': 35, 'Sex_x': 'Male', 'Location': 'California', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221d4'), 'Age': 33, 'Sex_x': 'Male', 'Location': 'California', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a32afe891ca4594221d5'), 'Age': 39, 'Sex_x': 'Male', 'Location': 'California', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# ...
# {'_id': ObjectId('5fc5a401fe891ca4594222a0'), 'Age': 34, 'Sex_x': 'Male', 'Location': 'Michigan', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.1, 'Bad Days Min': 4.1, 'Bad Days Q1': 4.1, 'Bad Days Q2': 4.1, 'Bad Days Q3': 4.1, 'Bad Days Max': 4.1}
# {'_id': ObjectId('5fc5a401fe891ca4594222a1'), 'Age': 30, 'Sex_x': 'Male', 'Location': 'Utah', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222a2'), 'Age': 24, 'Sex_x': 'Male', 'Location': 'Utah', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222a3'), 'Age': 40, 'Sex_x': 'Male', 'Location': 'Utah', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222a4'), 'Age': 47, 'Sex_x': 'Male', 'Location': 'Alabama', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 4.6, 'Bad Days Min': 4.6, 'Bad Days Q1': 4.6, 'Bad Days Q2': 4.6, 'Bad Days Q3': 4.6, 'Bad Days Max': 4.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222a5'), 'Age': 41, 'Sex_x': 'Male', 'Location': 'Indiana', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222a6'), 'Age': 41, 'Sex_x': 'Male', 'Location': 'Indiana', 'Emp Coverage': "I don't know", 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222a7'), 'Age': 30, 'Sex_x': 'Male', 'Location': 'Minnesota', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.2, 'Bad Days Min': 3.2, 'Bad Days Q1': 3.2, 'Bad Days Q2': 3.2, 'Bad Days Q3': 3.2, 'Bad Days Max': 3.2}
# {'_id': ObjectId('5fc5a401fe891ca4594222a8'), 'Age': 32, 'Sex_x': 'Male', 'Location': 'Kansas', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222a9'), 'Age': 40, 'Sex_x': 'Male', 'Location': 'Kansas', 'Emp Coverage': "I don't know", 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222aa'), 'Age': 40, 'Sex_x': 'Male', 'Location': 'Kansas', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222ab'), 'Age': 35, 'Sex_x': 'Male', 'Location': 'Kansas', 'Emp Coverage': 'Not eligible for coverage / NA', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222ac'), 'Age': 45, 'Sex_x': 'Male', 'Location': 'Kansas', 'Emp Coverage': 'No', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222ad'), 'Age': 26, 'Sex_x': 'Male', 'Location': 'Alaska', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.3, 'Bad Days Min': 3.3, 'Bad Days Q1': 3.3, 'Bad Days Q2': 3.3, 'Bad Days Q3': 3.3, 'Bad Days Max': 3.3}
# {'_id': ObjectId('5fc5a401fe891ca4594222ae'), 'Age': 40, 'Sex_x': 'Male', 'Location': 'Missouri', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a401fe891ca4594222af'), 'Age': 28, 'Sex_x': 'Male', 'Location': 'Virginia', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a401fe891ca4594222b0'), 'Age': 39, 'Sex_x': 'Male', 'Location': 'Virginia', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a401fe891ca4594222b1'), 'Age': 22, 'Sex_x': 'Male', 'Location': 'Virginia', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': "Don't Know", 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a401fe891ca4594222b2'), 'Age': 26, 'Sex_x': 'Male', 'Location': 'Virginia', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a401fe891ca4594222b3'), 'Age': 24, 'Sex_x': 'Male', 'Location': 'Virginia', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a401fe891ca4594222b4'), 'Age': 30, 'Sex_x': 'Male', 'Location': 'Washington', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222b5'), 'Age': 38, 'Sex_x': 'Male', 'Location': 'Washington', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222b6'), 'Age': 45, 'Sex_x': 'Male', 'Location': 'Washington', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222b7'), 'Age': 38, 'Sex_x': 'Male', 'Location': 'Washington', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': "Don't Know", 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222b8'), 'Age': 47, 'Sex_x': 'Male', 'Location': 'Washington', 'Emp Coverage': "I don't know", 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.6, 'Bad Days Min': 3.6, 'Bad Days Q1': 3.6, 'Bad Days Q2': 3.6, 'Bad Days Q3': 3.6, 'Bad Days Max': 3.6}
# {'_id': ObjectId('5fc5a401fe891ca4594222b9'), 'Age': 35, 'Sex_x': 'Male', 'Location': 'Ohio', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a401fe891ca4594222ba'), 'Age': 37, 'Sex_x': 'Male', 'Location': 'Ohio', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a401fe891ca4594222bb'), 'Age': 29, 'Sex_x': 'Male', 'Location': 'Ohio', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a401fe891ca4594222bc'), 'Age': 41, 'Sex_x': 'Male', 'Location': 'Ohio', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a401fe891ca4594222bd'), 'Age': 21, 'Sex_x': 'Male', 'Location': 'Ohio', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 4.3, 'Bad Days Min': 4.3, 'Bad Days Q1': 4.3, 'Bad Days Q2': 4.3, 'Bad Days Q3': 4.3, 'Bad Days Max': 4.3}
# {'_id': ObjectId('5fc5a401fe891ca4594222be'), 'Age': 27, 'Sex_x': 'Male', 'Location': 'Pennsylvania', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a401fe891ca4594222bf'), 'Age': 28, 'Sex_x': 'Male', 'Location': 'Pennsylvania', 'Emp Coverage': "I don't know", 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a401fe891ca4594222c0'), 'Age': 30, 'Sex_x': 'Male', 'Location': 'Pennsylvania', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a401fe891ca4594222c1'), 'Age': 32, 'Sex_x': 'Male', 'Location': 'Maryland', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a401fe891ca4594222c2'), 'Age': 29, 'Sex_x': 'Male', 'Location': 'Maryland', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a401fe891ca4594222c3'), 'Age': 42, 'Sex_x': 'Male', 'Location': 'Oklahoma', 'Emp Coverage': "I don't know", 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.9, 'Bad Days Min': 3.9, 'Bad Days Q1': 3.9, 'Bad Days Q2': 3.9, 'Bad Days Q3': 3.9, 'Bad Days Max': 3.9}
# {'_id': ObjectId('5fc5a401fe891ca4594222c4'), 'Age': 36, 'Sex_x': 'Male', 'Location': 'Iowa', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.2, 'Bad Days Min': 3.2, 'Bad Days Q1': 3.2, 'Bad Days Q2': 3.2, 'Bad Days Q3': 3.2, 'Bad Days Max': 3.2}
# {'_id': ObjectId('5fc5a401fe891ca4594222c5'), 'Age': 34, 'Sex_x': 'Male', 'Location': 'Texas', 'Emp Coverage': 'Yes', 'Ranking': 4, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.4, 'Bad Days Min': 3.4, 'Bad Days Q1': 3.4, 'Bad Days Q2': 3.4, 'Bad Days Q3': 3.4, 'Bad Days Max': 3.4}
# {'_id': ObjectId('5fc5a401fe891ca4594222c6'), 'Age': 39, 'Sex_x': 'Male', 'Location': 'Massachusetts', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a401fe891ca4594222c7'), 'Age': 32, 'Sex_x': 'Male', 'Location': 'Massachusetts', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.5, 'Bad Days Min': 3.5, 'Bad Days Q1': 3.5, 'Bad Days Q2': 3.5, 'Bad Days Q3': 3.5, 'Bad Days Max': 3.5}
# {'_id': ObjectId('5fc5a401fe891ca4594222c8'), 'Age': 39, 'Sex_x': 'Male', 'Location': 'Maine', 'Emp Coverage': nan, 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Yes', 'Bad Days Count': 1, 'Bad Days Mean': 3.8, 'Bad Days Min': 3.8, 'Bad Days Q1': 3.8, 'Bad Days Q2': 3.8, 'Bad Days Q3': 3.8, 'Bad Days Max': 3.8}
# {'_id': ObjectId('5fc5a401fe891ca4594222c9'), 'Age': 22, 'Sex_x': 'Male', 'Location': 'Maine', 'Emp Coverage': "I don't know", 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 3.8, 'Bad Days Min': 3.8, 'Bad Days Q1': 3.8, 'Bad Days Q2': 3.8, 'Bad Days Q3': 3.8, 'Bad Days Max': 3.8}
# {'_id': ObjectId('5fc5a401fe891ca4594222ca'), 'Age': 42, 'Sex_x': 'Male', 'Location': 'Arizona', 'Emp Coverage': 'Yes', 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 4.1, 'Bad Days Min': 4.1, 'Bad Days Q1': 4.1, 'Bad Days Q2': 4.1, 'Bad Days Q3': 4.1, 'Bad Days Max': 4.1}
# {'_id': ObjectId('5fc5a401fe891ca4594222cb'), 'Age': 55, 'Sex_x': 'Male', 'Location': 'Arizona', 'Emp Coverage': 'Yes', 'Ranking': 1, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.1, 'Bad Days Min': 4.1, 'Bad Days Q1': 4.1, 'Bad Days Q2': 4.1, 'Bad Days Q3': 4.1, 'Bad Days Max': 4.1}
# {'_id': ObjectId('5fc5a401fe891ca4594222cc'), 'Age': 37, 'Sex_x': 'Male', 'Location': 'South Carolina', 'Emp Coverage': 'Yes', 'Ranking': 2, 'Do you *currently* have a mental health disorder?': 'Possibly', 'Bad Days Count': 1, 'Bad Days Mean': 3.3, 'Bad Days Min': 3.3, 'Bad Days Q1': 3.3, 'Bad Days Q2': 3.3, 'Bad Days Q3': 3.3, 'Bad Days Max': 3.3}
# {'_id': ObjectId('5fc5a401fe891ca4594222cd'), 'Age': 48, 'Sex_x': 'Male', 'Location': 'Louisiana', 'Emp Coverage': nan, 'Ranking': 3, 'Do you *currently* have a mental health disorder?': 'No', 'Bad Days Count': 1, 'Bad Days Mean': 4.8, 'Bad Days Min': 4.8, 'Bad Days Q1': 4.8, 'Bad Days Q2': 4.8, 'Bad Days Q3': 4.8, 'Bad Days Max': 4.8}
