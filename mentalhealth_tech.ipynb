# %%
import os
from bs4 import BeautifulSoup as bs
import requests
import pymongo
from splinter import Browser
import pandas as pd
import time

# %%
# Make a reference to thecsv file path
csv_path = "MentalHealthCSV.csv"

# Import the books.csv file as a DataFrame
MentalHealth_df = pd.read_csv(csv_path)
MentalHealth_df.head()
# Out:
#    *Are you self-employed?*  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                            100-500
# 4                                             26-100
#
#   Is your employer primarily a tech company/organization?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to tech/IT?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                       I don't know
# 4                                       I don't know
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                       I don't know
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                                Yes
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                          Very easy
# 1                                       I don't know
# 2                                 Somewhat difficult
# 3                                          Very easy
# 4                                       I don't know
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.  \
# 0                                                NaN
# 1                                                NaN
# 2  I think opening up more conversation around th...
# 3                                                NaN
# 4                                                NaN
#
#   If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.  \
# 0                                                NaN
# 1                                                NaN
# 2                                          Thank you
# 3                                                NaN
# 4                                                NaN
#
#   Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   What is your age? What is your gender? What country do you *live* in?  \
# 0                25                 Male       United States of America
# 1                51                 male       United States of America
# 2                27                 Male       United States of America
# 3                37                 male       United States of America
# 4                46                    m       United States of America
#
#   What US state or territory do you *live* in? What is your race?  \
# 0                                     Nebraska              White
# 1                                     Nebraska              White
# 2                                     Illinois              White
# 3                                     Nebraska              White
# 4                                     Nebraska              White
#
#   What country do you *work* in?  What US state or territory do you *work* in?
# 0       United States of America                                      Nebraska
# 1       United States of America                                      Nebraska
# 2       United States of America                                      Illinois
# 3       United States of America                                      Nebraska
# 4       United States of America                                      Nebraska
#
# [5 rows x 82 columns]

# %%
#Count for rosw missing data 
MentalHealth_df.count()
# Out:
# *Are you self-employed?*                                                             352
# How many employees does your company or organization have?                           304
# Is your employer primarily a tech company/organization?                              304
# Is your primary role within your company related to tech/IT?                         304
# Does your employer provide mental health benefits as part of healthcare coverage?    304
#                                                                                     ...
# What country do you *live* in?                                                       352
# What US state or territory do you *live* in?                                         204
# What is your race?                                                                   204
# What country do you *work* in?                                                       352
# What US state or territory do you *work* in?                                         204
# Length: 82, dtype: int64

# %%
MentalHealth_df.head()

#all of them
# Out:
#    *Are you self-employed?*  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                            100-500
# 4                                             26-100
#
#   Is your employer primarily a tech company/organization?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to tech/IT?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                       I don't know
# 4                                       I don't know
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                       I don't know
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                                Yes
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                          Very easy
# 1                                       I don't know
# 2                                 Somewhat difficult
# 3                                          Very easy
# 4                                       I don't know
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.  \
# 0                                                NaN
# 1                                                NaN
# 2  I think opening up more conversation around th...
# 3                                                NaN
# 4                                                NaN
#
#   If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.  \
# 0                                                NaN
# 1                                                NaN
# 2                                          Thank you
# 3                                                NaN
# 4                                                NaN
#
#   Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   What is your age? What is your gender? What country do you *live* in?  \
# 0                25                 Male       United States of America
# 1                51                 male       United States of America
# 2                27                 Male       United States of America
# 3                37                 male       United States of America
# 4                46                    m       United States of America
#
#   What US state or territory do you *live* in? What is your race?  \
# 0                                     Nebraska              White
# 1                                     Nebraska              White
# 2                                     Illinois              White
# 3                                     Nebraska              White
# 4                                     Nebraska              White
#
#   What country do you *work* in?  What US state or territory do you *work* in?
# 0       United States of America                                      Nebraska
# 1       United States of America                                      Nebraska
# 2       United States of America                                      Illinois
# 3       United States of America                                      Nebraska
# 4       United States of America                                      Nebraska
#
# [5 rows x 82 columns]

# %%
MH_Clean = MentalHealth_df.rename(columns={
    "What is your age?": "Age",
    "What is your gender?": "Sex", 
    "What US state or territory do you *live* in?": "Location",
    "Does your employer provide mental health benefits as part of healthcare coverage?": "Emp_Coverage",
    "Overall, how well do you think the tech industry supports employees with mental health issues?": "Ranking",
    "Do you *currently* have a mental health disorder?": "current_mental_health",
    
    })
MH_Clean.head()
# Out:
#    *Are you self-employed?*  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                            100-500
# 4                                             26-100
#
#   Is your employer primarily a tech company/organization?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to tech/IT?  Emp_Coverage  \
# 0                                               True            I don't know
# 1                                               True                     Yes
# 2                                               True            I don't know
# 3                                               True            I don't know
# 4                                               True            I don't know
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                       I don't know
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                                Yes
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                          Very easy
# 1                                       I don't know
# 2                                 Somewhat difficult
# 3                                          Very easy
# 4                                       I don't know
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.  \
# 0                                                NaN
# 1                                                NaN
# 2  I think opening up more conversation around th...
# 3                                                NaN
# 4                                                NaN
#
#   If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.  \
# 0                                                NaN
# 1                                                NaN
# 2                                          Thank you
# 3                                                NaN
# 4                                                NaN
#
#   Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   Age   Sex What country do you *live* in?  Location What is your race?  \
# 0  25  Male       United States of America  Nebraska              White
# 1  51  male       United States of America  Nebraska              White
# 2  27  Male       United States of America  Illinois              White
# 3  37  male       United States of America  Nebraska              White
# 4  46     m       United States of America  Nebraska              White
#
#   What country do you *work* in?  What US state or territory do you *work* in?
# 0       United States of America                                      Nebraska
# 1       United States of America                                      Nebraska
# 2       United States of America                                      Illinois
# 3       United States of America                                      Nebraska
# 4       United States of America                                      Nebraska
#
# [5 rows x 82 columns]

# %%
#Need Columns only 
MentalHealthClean2 = MH_Clean[["Age", "Sex", "Location", "Emp_Coverage","Ranking", "current_mental_health"]]
print(MentalHealthClean2)
# Out:
#      Age           Sex   Location  Emp_Coverage  Ranking current_mental_health
# 0     25          Male   Nebraska  I don't know        4            Don't Know
# 1     51          male   Nebraska           Yes        1              Possibly
# 2     27          Male   Illinois  I don't know        2                    No
# 3     37          male   Nebraska  I don't know        3                    No
# 4     46             m   Nebraska  I don't know        3                    No
# ..   ...           ...        ...           ...      ...                   ...
# 347   27          male        NaN  I don't know        3              Possibly
# 348   48             m  Louisiana           NaN        3                    No
# 349   50             M        NaN           NaN        5                    No
# 350   30        female        NaN            No        2              Possibly
# 351   24  Female (cis)     Oregon           Yes        3                   Yes
#
# [352 rows x 6 columns]

# %%
MentalHealthClean2['current_mental_health'].unique()
# Out:
# array(["Don't Know", 'Possibly', 'No', 'Yes'], dtype=object)

# %%
# Unique labels 
MentalHealthClean2['Sex'].unique()
# Out:
# array(['Male', 'male', 'm', 'female', 'Female', nan, 'M', 'F', 'f',
#        'Let\'s keep it simple and say "male"', 'Non-binary',
#        'Identify as male', 'Male ', 'Woman', 'Non binary', 'Masculine',
#        'Cishet male', 'None', 'Female-identified', 'woman', 'Nonbinary',
#        'agender', 'Man', 'Questioning', 'cis male', 'Cis Male',
#        'I have a penis', 'rr', 'cis woman', 'Agender trans woman',
#        'Female ', 'femmina', '43', 'Trans man', 'man', 'masculino',
#        'I am a Wookie', 'Make', 'Trans non-binary/genderfluid',
#        'CIS Male', 'Non-binary and gender fluid', 'Femile',
#        'Female (cis)'], dtype=object)

# %%
#Change male leaning
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['m'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['M'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Let\'s keep it simple and say "male"'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Masculine'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cishet male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Man'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['cis male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Trans Man'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['I have a penis'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['man'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['masculino'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['CIS Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cis Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cis Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cis Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Male '],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Trans man'],'Male')
# Out:
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Change female leaning
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['f'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['F'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Female-identified'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Agender trans woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Female (cis)'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Femile'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['femmina'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['female'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['cis woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Female '],'Female')
# Out:
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\Doggger\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
MentalHealthClean2['Sex']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 347      Male
# 348      Male
# 349      Male
# 350    Female
# 351    Female
# Name: Sex, Length: 352, dtype: object

# %%
# Number by gender
MentalHealthClean2['Sex'].unique()
# Out:
# array(['Male', 'Female', nan, 'Non-binary', 'Identify as male',
#        'Non binary', 'None', 'Nonbinary', 'agender', 'Questioning', 'rr',
#        '43', 'I am a Wookie', 'Make', 'Trans non-binary/genderfluid',
#        'Non-binary and gender fluid'], dtype=object)

# %%
#Dropping other labels 
L= ['Non-binary', 'Non binary', 'None',
       'Nonbinary', 'agender', 'Questioning', 'rr', '43', 'I am a Wookie',
       'Make', 'Trans non-binary/genderfluid',
       'Non-binary and gender fluid', 'Identify as male']

MentalHealthClean2=MentalHealthClean2[MentalHealthClean2['Sex'].isin(L)==False]
MentalHealthClean2
# Out:
#      Age     Sex   Location  Emp_Coverage  Ranking current_mental_health
# 0     25    Male   Nebraska  I don't know        4            Don't Know
# 1     51    Male   Nebraska           Yes        1              Possibly
# 2     27    Male   Illinois  I don't know        2                    No
# 3     37    Male   Nebraska  I don't know        3                    No
# 4     46    Male   Nebraska  I don't know        3                    No
# ..   ...     ...        ...           ...      ...                   ...
# 347   27    Male        NaN  I don't know        3              Possibly
# 348   48    Male  Louisiana           NaN        3                    No
# 349   50    Male        NaN           NaN        5                    No
# 350   30  Female        NaN            No        2              Possibly
# 351   24  Female     Oregon           Yes        3                   Yes
#
# [336 rows x 6 columns]

# %%
MentalHealthClean2['Sex'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
#Dropping other labels 
L= ["Don't Know", 'Possibly']


MentalHealthClean2=MentalHealthClean2[MentalHealthClean2['current_mental_health'].isin(L)==False]
MentalHealthClean2['current_mental_health'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
MentalHealthClean2.count()
# Out:
# Age                      238
# Sex                      233
# Location                 149
# Emp_Coverage             207
# Ranking                  238
# current_mental_health    238
# dtype: int64

# %%
MentalHealthClean2=MentalHealthClean2.dropna(subset=['Location', 'Sex'])

# %%
MentalHealthClean2.count()
# Out:
# Age                      148
# Sex                      148
# Location                 148
# Emp_Coverage             132
# Ranking                  148
# current_mental_health    148
# dtype: int64

# %%
MentalHealthClean2.to_csv('MentalH.csv', index=False)

# %%
# Make a reference to thecsv file path
csv_path = "MentalH.csv"

# Import the books.csv file as a DataFrame
test_df = pd.read_csv(csv_path)
test_df.count()
# Out:
# Age                      148
# Sex                      148
# Location                 148
# Emp_Coverage             132
# Ranking                  148
# current_mental_health    148
# dtype: int64

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
mentalhealth_db = client.osmi_table

osmi_table = mentalhealth_db.osmi_table

# %%
mentalhealth_db.osmi_db.drop
# MentalHealthClean2.reset_index(inplace=True)
data_dict = MentalHealthClean2.to_dict("records")
# Insert collection
osmi_table.insert_many(data_dict)

# %%
results = osmi_table.find()
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('5fc50de0c9b8286ea9742161'), 'Age': 27, 'Sex': 'Male', 'Location': 'Illinois', 'Emp_Coverage': "I don't know", 'Ranking': 2, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742162'), 'Age': 37, 'Sex': 'Male', 'Location': 'Nebraska', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742163'), 'Age': 46, 'Sex': 'Male', 'Location': 'Nebraska', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742164'), 'Age': 36, 'Sex': 'Female', 'Location': 'Nebraska', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742165'), 'Age': 39, 'Sex': 'Female', 'Location': 'Nebraska', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742166'), 'Age': 37, 'Sex': 'Male', 'Location': 'Georgia', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742167'), 'Age': 26, 'Sex': 'Female', 'Location': 'Pennsylvania', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742168'), 'Age': 37, 'Sex': 'Male', 'Location': 'Wisconsin', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742169'), 'Age': 41, 'Sex': 'Male', 'Location': 'Tennessee', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974216a'), 'Age': 40, 'Sex': 'Female', 'Location': 'New York', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974216b'), 'Age': 37, 'Sex': 'Male', 'Location': 'New York', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974216c'), 'Age': 29, 'Sex': 'Male', 'Location': 'Tennessee', 'Emp_Coverage': "I don't know", 'Ranking': 1, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974216d'), 'Age': 37, 'Sex': 'Male', 'Location': 'New York', 'Emp_Coverage': "I don't know", 'Ranking': 5, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974216e'), 'Age': 45, 'Sex': 'Female', 'Location': 'Wisconsin', 'Emp_Coverage': "I don't know", 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974216f'), 'Age': 28, 'Sex': 'Male', 'Location': 'Colorado', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742170'), 'Age': 24, 'Sex': 'Female', 'Location': 'Massachusetts', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742171'), 'Age': 42, 'Sex': 'Male', 'Location': 'Florida', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742172'), 'Age': 53, 'Sex': 'Female', 'Location': 'Minnesota', 'Emp_Coverage': nan, 'Ranking': 4, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742173'), 'Age': 58, 'Sex': 'Male', 'Location': 'Illinois', 'Emp_Coverage': nan, 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742174'), 'Age': 50, 'Sex': 'Male', 'Location': 'Tennessee', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742175'), 'Age': 41, 'Sex': 'Male', 'Location': 'California', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742176'), 'Age': 37, 'Sex': 'Male', 'Location': 'New York', 'Emp_Coverage': "I don't know", 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742177'), 'Age': 36, 'Sex': 'Male', 'Location': 'Illinois', 'Emp_Coverage': nan, 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742178'), 'Age': 37, 'Sex': 'Male', 'Location': 'Michigan', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742179'), 'Age': 53, 'Sex': 'Female', 'Location': 'Wyoming', 'Emp_Coverage': "I don't know", 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974217a'), 'Age': 35, 'Sex': 'Male', 'Location': 'California', 'Emp_Coverage': 'Yes', 'Ranking': 1, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974217b'), 'Age': 34, 'Sex': 'Female', 'Location': 'Colorado', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974217c'), 'Age': 35, 'Sex': 'Male', 'Location': 'Colorado', 'Emp_Coverage': 'No', 'Ranking': 2, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974217d'), 'Age': 28, 'Sex': 'Female', 'Location': 'Colorado', 'Emp_Coverage': "I don't know", 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974217e'), 'Age': 50, 'Sex': 'Male', 'Location': 'Colorado', 'Emp_Coverage': nan, 'Ranking': 2, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974217f'), 'Age': 24, 'Sex': 'Female', 'Location': 'Colorado', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742180'), 'Age': 39, 'Sex': 'Male', 'Location': 'California', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742181'), 'Age': 26, 'Sex': 'Female', 'Location': 'Colorado', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742182'), 'Age': 32, 'Sex': 'Female', 'Location': 'Michigan', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742183'), 'Age': 41, 'Sex': 'Male', 'Location': 'Indiana', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742184'), 'Age': 31, 'Sex': 'Female', 'Location': 'California', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742185'), 'Age': 30, 'Sex': 'Male', 'Location': 'Tennessee', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742186'), 'Age': 45, 'Sex': 'Female', 'Location': 'Vermont', 'Emp_Coverage': "I don't know", 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742187'), 'Age': 30, 'Sex': 'Male', 'Location': 'Minnesota', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742188'), 'Age': 41, 'Sex': 'Male', 'Location': 'Indiana', 'Emp_Coverage': "I don't know", 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742189'), 'Age': 32, 'Sex': 'Male', 'Location': 'Nebraska', 'Emp_Coverage': "I don't know", 'Ranking': 4, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974218a'), 'Age': 20, 'Sex': 'Female', 'Location': 'Nebraska', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974218b'), 'Age': 24, 'Sex': 'Female', 'Location': 'Georgia', 'Emp_Coverage': nan, 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974218c'), 'Age': 0, 'Sex': 'Male', 'Location': 'Nebraska', 'Emp_Coverage': "I don't know", 'Ranking': 4, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974218d'), 'Age': 38, 'Sex': 'Male', 'Location': 'Nebraska', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974218e'), 'Age': 31, 'Sex': 'Male', 'Location': 'Nebraska', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974218f'), 'Age': 26, 'Sex': 'Male', 'Location': 'Alaska', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742190'), 'Age': 40, 'Sex': 'Male', 'Location': 'Missouri', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742191'), 'Age': 30, 'Sex': 'Male', 'Location': 'Nebraska', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742192'), 'Age': 38, 'Sex': 'Male', 'Location': 'Nebraska', 'Emp_Coverage': 'Yes', 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742193'), 'Age': 28, 'Sex': 'Male', 'Location': 'Virginia', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742194'), 'Age': 30, 'Sex': 'Male', 'Location': 'Washington', 'Emp_Coverage': 'Yes', 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742195'), 'Age': 33, 'Sex': 'Female', 'Location': 'Oregon', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742196'), 'Age': 53, 'Sex': 'Female', 'Location': 'Washington', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742197'), 'Age': 38, 'Sex': 'Male', 'Location': 'Washington', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742198'), 'Age': 40, 'Sex': 'Male', 'Location': 'Kansas', 'Emp_Coverage': "I don't know", 'Ranking': 4, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea9742199'), 'Age': 42, 'Sex': 'Male', 'Location': 'Florida', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974219a'), 'Age': 42, 'Sex': 'Male', 'Location': 'Illinois', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974219b'), 'Age': 35, 'Sex': 'Male', 'Location': 'Ohio', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974219c'), 'Age': 40, 'Sex': 'Male', 'Location': 'Tennessee', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974219d'), 'Age': 54, 'Sex': 'Female', 'Location': 'Illinois', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea974219e'), 'Age': 37, 'Sex': 'Male', 'Location': 'Ohio', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea974219f'), 'Age': 26, 'Sex': 'Female', 'Location': 'New York', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421a0'), 'Age': 49, 'Sex': 'Female', 'Location': 'Ohio', 'Emp_Coverage': 'Yes', 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421a1'), 'Age': 23, 'Sex': 'Male', 'Location': 'New Jersey', 'Emp_Coverage': "I don't know", 'Ranking': 4, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421a2'), 'Age': 27, 'Sex': 'Male', 'Location': 'Pennsylvania', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421a3'), 'Age': 28, 'Sex': 'Male', 'Location': 'Pennsylvania', 'Emp_Coverage': "I don't know", 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421a4'), 'Age': 38, 'Sex': 'Male', 'Location': 'Illinois', 'Emp_Coverage': nan, 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421a5'), 'Age': 45, 'Sex': 'Male', 'Location': 'Colorado', 'Emp_Coverage': 'No', 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421a6'), 'Age': 34, 'Sex': 'Female', 'Location': 'California', 'Emp_Coverage': nan, 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421a7'), 'Age': 32, 'Sex': 'Male', 'Location': 'Maryland', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421a8'), 'Age': 22, 'Sex': 'Female', 'Location': 'California', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421a9'), 'Age': 28, 'Sex': 'Male', 'Location': 'California', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421aa'), 'Age': 29, 'Sex': 'Female', 'Location': 'Maryland', 'Emp_Coverage': "I don't know", 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ab'), 'Age': 32, 'Sex': 'Male', 'Location': 'Illinois', 'Emp_Coverage': nan, 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ac'), 'Age': 38, 'Sex': 'Female', 'Location': 'Illinois', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ad'), 'Age': 30, 'Sex': 'Male', 'Location': 'Illinois', 'Emp_Coverage': "I don't know", 'Ranking': 2, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ae'), 'Age': 37, 'Sex': 'Female', 'Location': 'District of Columbia', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421af'), 'Age': 38, 'Sex': 'Female', 'Location': 'Texas', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421b0'), 'Age': 51, 'Sex': 'Female', 'Location': 'Florida', 'Emp_Coverage': 'Yes', 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421b1'), 'Age': 39, 'Sex': 'Male', 'Location': 'Virginia', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421b2'), 'Age': 26, 'Sex': 'Male', 'Location': 'Virginia', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421b3'), 'Age': 63, 'Sex': 'Male', 'Location': 'Georgia', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421b4'), 'Age': 36, 'Sex': 'Male', 'Location': 'Iowa', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421b5'), 'Age': 30, 'Sex': 'Female', 'Location': 'Illinois', 'Emp_Coverage': nan, 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421b6'), 'Age': 36, 'Sex': 'Male', 'Location': 'New York', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421b7'), 'Age': 40, 'Sex': 'Male', 'Location': 'Kansas', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421b8'), 'Age': 34, 'Sex': 'Male', 'Location': 'Nebraska', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421b9'), 'Age': 34, 'Sex': 'Male', 'Location': 'Texas', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ba'), 'Age': 34, 'Sex': 'Female', 'Location': 'Minnesota', 'Emp_Coverage': nan, 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421bb'), 'Age': 27, 'Sex': 'Female', 'Location': 'Georgia', 'Emp_Coverage': 'Yes', 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421bc'), 'Age': 31, 'Sex': 'Female', 'Location': 'Minnesota', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421bd'), 'Age': 26, 'Sex': 'Female', 'Location': 'Michigan', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421be'), 'Age': 39, 'Sex': 'Male', 'Location': 'Massachusetts', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421bf'), 'Age': 36, 'Sex': 'Female', 'Location': 'New York', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421c0'), 'Age': 25, 'Sex': 'Female', 'Location': 'Michigan', 'Emp_Coverage': 'Not eligible for coverage / NA', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421c1'), 'Age': 19, 'Sex': 'Female', 'Location': 'Nebraska', 'Emp_Coverage': 'Not eligible for coverage / NA', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421c2'), 'Age': 35, 'Sex': 'Male', 'Location': 'Kansas', 'Emp_Coverage': 'Not eligible for coverage / NA', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421c3'), 'Age': 38, 'Sex': 'Male', 'Location': 'Tennessee', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421c4'), 'Age': 32, 'Sex': 'Male', 'Location': 'Massachusetts', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421c5'), 'Age': 39, 'Sex': 'Male', 'Location': 'Maine', 'Emp_Coverage': nan, 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421c6'), 'Age': 33, 'Sex': 'Male', 'Location': 'Tennessee', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421c7'), 'Age': 53, 'Sex': 'Male', 'Location': 'New Jersey', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421c8'), 'Age': 35, 'Sex': 'Male', 'Location': 'New York', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421c9'), 'Age': 29, 'Sex': 'Male', 'Location': 'Ohio', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ca'), 'Age': 30, 'Sex': 'Male', 'Location': 'North Carolina', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421cb'), 'Age': 29, 'Sex': 'Female', 'Location': 'California', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421cc'), 'Age': 24, 'Sex': 'Male', 'Location': 'Virginia', 'Emp_Coverage': "I don't know", 'Ranking': 2, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421cd'), 'Age': 25, 'Sex': 'Female', 'Location': 'Washington', 'Emp_Coverage': 'Not eligible for coverage / NA', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ce'), 'Age': 37, 'Sex': 'Male', 'Location': 'California', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421cf'), 'Age': 22, 'Sex': 'Male', 'Location': 'Maine', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421d0'), 'Age': 35, 'Sex': 'Female', 'Location': 'Oregon', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421d1'), 'Age': 50, 'Sex': 'Male', 'Location': 'Nebraska', 'Emp_Coverage': "I don't know", 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421d2'), 'Age': 45, 'Sex': 'Male', 'Location': 'Washington', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421d3'), 'Age': 27, 'Sex': 'Male', 'Location': 'California', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421d4'), 'Age': 28, 'Sex': 'Female', 'Location': 'Washington', 'Emp_Coverage': 'No', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421d5'), 'Age': 30, 'Sex': 'Female', 'Location': 'California', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421d6'), 'Age': 45, 'Sex': 'Male', 'Location': 'North Carolina', 'Emp_Coverage': 'Not eligible for coverage / NA', 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421d7'), 'Age': 26, 'Sex': 'Female', 'Location': 'Washington', 'Emp_Coverage': "I don't know", 'Ranking': 1, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421d8'), 'Age': 32, 'Sex': 'Female', 'Location': 'Washington', 'Emp_Coverage': 'Yes', 'Ranking': 1, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421d9'), 'Age': 43, 'Sex': 'Female', 'Location': 'Washington', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421da'), 'Age': 37, 'Sex': 'Male', 'Location': 'Michigan', 'Emp_Coverage': nan, 'Ranking': 5, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421db'), 'Age': 56, 'Sex': 'Male', 'Location': 'North Carolina', 'Emp_Coverage': nan, 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421dc'), 'Age': 28, 'Sex': 'Female', 'Location': 'District of Columbia', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421dd'), 'Age': 26, 'Sex': 'Female', 'Location': 'Virginia', 'Emp_Coverage': 'No', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421de'), 'Age': 45, 'Sex': 'Male', 'Location': 'Kansas', 'Emp_Coverage': 'No', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421df'), 'Age': 34, 'Sex': 'Male', 'Location': 'Michigan', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421e0'), 'Age': 34, 'Sex': 'Female', 'Location': 'Massachusetts', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421e1'), 'Age': 41, 'Sex': 'Male', 'Location': 'Ohio', 'Emp_Coverage': "I don't know", 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421e2'), 'Age': 42, 'Sex': 'Female', 'Location': 'California', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421e3'), 'Age': 21, 'Sex': 'Male', 'Location': 'Ohio', 'Emp_Coverage': "I don't know", 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421e4'), 'Age': 30, 'Sex': 'Female', 'Location': 'Illinois', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421e5'), 'Age': 46, 'Sex': 'Male', 'Location': 'New York', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421e6'), 'Age': 36, 'Sex': 'Female', 'Location': 'New York', 'Emp_Coverage': nan, 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421e7'), 'Age': 47, 'Sex': 'Female', 'Location': 'North Carolina', 'Emp_Coverage': "I don't know", 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421e8'), 'Age': 24, 'Sex': 'Male', 'Location': 'Utah', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421e9'), 'Age': 40, 'Sex': 'Male', 'Location': 'Utah', 'Emp_Coverage': 'Yes', 'Ranking': 4, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ea'), 'Age': 37, 'Sex': 'Male', 'Location': 'Colorado', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421eb'), 'Age': 47, 'Sex': 'Male', 'Location': 'Washington', 'Emp_Coverage': "I don't know", 'Ranking': 1, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ec'), 'Age': 30, 'Sex': 'Female', 'Location': 'Washington', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ed'), 'Age': 38, 'Sex': 'Female', 'Location': 'Idaho', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ee'), 'Age': 47, 'Sex': 'Male', 'Location': 'California', 'Emp_Coverage': 'Yes', 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421ef'), 'Age': 55, 'Sex': 'Male', 'Location': 'Arizona', 'Emp_Coverage': 'Yes', 'Ranking': 1, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421f0'), 'Age': 27, 'Sex': 'Male', 'Location': 'Colorado', 'Emp_Coverage': nan, 'Ranking': 2, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421f1'), 'Age': 42, 'Sex': 'Female', 'Location': 'Texas', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421f2'), 'Age': 31, 'Sex': 'Female', 'Location': 'California', 'Emp_Coverage': 'No', 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421f3'), 'Age': 48, 'Sex': 'Male', 'Location': 'Louisiana', 'Emp_Coverage': nan, 'Ranking': 3, 'current_mental_health': 'No'}
# {'_id': ObjectId('5fc50de0c9b8286ea97421f4'), 'Age': 24, 'Sex': 'Female', 'Location': 'Oregon', 'Emp_Coverage': 'Yes', 'Ranking': 3, 'current_mental_health': 'Yes'}
