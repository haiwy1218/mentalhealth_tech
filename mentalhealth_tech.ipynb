# %%
import os
from bs4 import BeautifulSoup as bs
import requests
import pymongo
from splinter import Browser
import pandas as pd
import time

# %%
# Make a reference to thecsv file path
csv_path = "MentalHealthCSV.csv"

# Import the books.csv file as a DataFrame
MentalHealth_df = pd.read_csv(csv_path)
MentalHealth_df.head()
# Out:
#    *Are you self-employed?*  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                            100-500
# 4                                             26-100
#
#   Is your employer primarily a tech company/organization?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to tech/IT?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                       I don't know
# 4                                       I don't know
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                       I don't know
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                                Yes
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                          Very easy
# 1                                       I don't know
# 2                                 Somewhat difficult
# 3                                          Very easy
# 4                                       I don't know
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.  \
# 0                                                NaN
# 1                                                NaN
# 2  I think opening up more conversation around th...
# 3                                                NaN
# 4                                                NaN
#
#   If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.  \
# 0                                                NaN
# 1                                                NaN
# 2                                          Thank you
# 3                                                NaN
# 4                                                NaN
#
#   Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   What is your age? What is your gender? What country do you *live* in?  \
# 0                25                 Male       United States of America
# 1                51                 male       United States of America
# 2                27                 Male       United States of America
# 3                37                 male       United States of America
# 4                46                    m       United States of America
#
#   What US state or territory do you *live* in? What is your race?  \
# 0                                     Nebraska              White
# 1                                     Nebraska              White
# 2                                     Illinois              White
# 3                                     Nebraska              White
# 4                                     Nebraska              White
#
#   What country do you *work* in?  What US state or territory do you *work* in?
# 0       United States of America                                      Nebraska
# 1       United States of America                                      Nebraska
# 2       United States of America                                      Illinois
# 3       United States of America                                      Nebraska
# 4       United States of America                                      Nebraska
#
# [5 rows x 82 columns]

# %%
#Count for rosw missing data 
MentalHealth_df.count()
# Out:
# *Are you self-employed?*                                                             352
# How many employees does your company or organization have?                           304
# Is your employer primarily a tech company/organization?                              304
# Is your primary role within your company related to tech/IT?                         304
# Does your employer provide mental health benefits as part of healthcare coverage?    304
#                                                                                     ...
# What country do you *live* in?                                                       352
# What US state or territory do you *live* in?                                         204
# What is your race?                                                                   204
# What country do you *work* in?                                                       352
# What US state or territory do you *work* in?                                         204
# Length: 82, dtype: int64

# %%
MentalHealth_df_c.isna().head()

#all of them
# Out:
#    *Are you self-employed?*  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#    How many employees does your company or organization have?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Is your employer primarily a tech company/organization?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                               True
#
#    If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                               True
#
#    Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    What is your age?  What is your gender?  What country do you *live* in?  \
# 0              False                 False                           False
# 1              False                 False                           False
# 2              False                 False                           False
# 3              False                 False                           False
# 4              False                 False                           False
#
#    What US state or territory do you *live* in?  What is your race?  \
# 0                                         False               False
# 1                                         False               False
# 2                                         False               False
# 3                                         False               False
# 4                                         False               False
#
#    What country do you *work* in?  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
#    What US state or territory do you *work* in?
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
# [5 rows x 82 columns]

# %%
MH_Clean = MentalHealth_df_c.rename(columns={
    "What is your age?": "Age",
    "What is your gender?": "Sex", 
    "What US state or territory do you *live* in?": "Location",
    "Does your employer provide mental health benefits as part of healthcare coverage?": "Emp. Coverage",
    "Overall, how well do you think the tech industry supports employees with mental health issues?": "Ranking",
    "Do you *currently* have a mental health disorder?": "Do you *currently* have a mental health disorder?",
    
    })
MH_Clean.head()
# Out:
#    *Are you self-employed?*  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                            100-500
# 4                                             26-100
#
#   Is your employer primarily a tech company/organization?  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to tech/IT? Emp. Coverage  \
# 0                                               True            I don't know
# 1                                               True                     Yes
# 2                                               True            I don't know
# 3                                               True            I don't know
# 4                                               True            I don't know
#
#   Do you know the options for mental health care available under your employer-provided health coverage?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                       I don't know
#
#   Does your employer offer resources to learn more about mental health disorders and options for seeking help?  \
# 0                                                Yes
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?  \
# 0                                       I don't know
# 1                                                Yes
# 2                                       I don't know
# 3                                                Yes
# 4                                       I don't know
#
#   If a mental health issue prompted you to request a medical leave from work, how easy or difficult would it be to ask for that leave?  \
# 0                                          Very easy
# 1                                       I don't know
# 2                                 Somewhat difficult
# 3                                          Very easy
# 4                                       I don't know
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Briefly describe what you think the industry as a whole and/or employers could do to improve mental health support for employees.  \
# 0                                                NaN
# 1                                                NaN
# 2  I think opening up more conversation around th...
# 3                                                NaN
# 4                                                NaN
#
#   If there is anything else you would like to tell us that has not been covered by the survey questions, please use this space to do so.  \
# 0                                                NaN
# 1                                                NaN
# 2                                          Thank you
# 3                                                NaN
# 4                                                NaN
#
#   Would you be willing to talk to one of us more extensively about your experiences with mental health issues in the tech industry? (Note that all interview responses would be used _anonymously_ and only with your permission.)  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   Age   Sex What country do you *live* in?  Location What is your race?  \
# 0  25  Male       United States of America  Nebraska              White
# 1  51  male       United States of America  Nebraska              White
# 2  27  Male       United States of America  Illinois              White
# 3  37  male       United States of America  Nebraska              White
# 4  46     m       United States of America  Nebraska              White
#
#   What country do you *work* in?  What US state or territory do you *work* in?
# 0       United States of America                                      Nebraska
# 1       United States of America                                      Nebraska
# 2       United States of America                                      Illinois
# 3       United States of America                                      Nebraska
# 4       United States of America                                      Nebraska
#
# [5 rows x 82 columns]

# %%
#Need Columns only 
MentalHealthClean2 = MH_Clean[["Age", "Sex", "Location", "Emp. Coverage","Ranking", "Do you *currently* have a mental health disorder?"]]
print(MentalHealthClean2)
# Out:
#      Age           Sex   Location Emp. Coverage  Ranking  \
# 0     25          Male   Nebraska  I don't know        4
# 1     51          male   Nebraska           Yes        1
# 2     27          Male   Illinois  I don't know        2
# 3     37          male   Nebraska  I don't know        3
# 4     46             m   Nebraska  I don't know        3
# ..   ...           ...        ...           ...      ...
# 347   27          male        NaN  I don't know        3
# 348   48             m  Louisiana           NaN        3
# 349   50             M        NaN           NaN        5
# 350   30        female        NaN            No        2
# 351   24  Female (cis)     Oregon           Yes        3
#
#     Do you *currently* have a mental health disorder?
# 0                                          Don't Know
# 1                                            Possibly
# 2                                                  No
# 3                                                  No
# 4                                                  No
# ..                                                ...
# 347                                          Possibly
# 348                                                No
# 349                                                No
# 350                                          Possibly
# 351                                               Yes
#
# [352 rows x 6 columns]

# %%
# Unique labels 
MentalHealthClean2['Sex'].unique()
# Out:
# array(['Male', 'male', 'm', 'female', 'Female', nan, 'M', 'F', 'f',
#        'Let\'s keep it simple and say "male"', 'Non-binary',
#        'Identify as male', 'Male ', 'Woman', 'Non binary', 'Masculine',
#        'Cishet male', 'None', 'Female-identified', 'woman', 'Nonbinary',
#        'agender', 'Man', 'Questioning', 'cis male', 'Cis Male',
#        'I have a penis', 'rr', 'cis woman', 'Agender trans woman',
#        'Female ', 'femmina', '43', 'Trans man', 'man', 'masculino',
#        'I am a Wookie', 'Make', 'Trans non-binary/genderfluid',
#        'CIS Male', 'Non-binary and gender fluid', 'Femile',
#        'Female (cis)'], dtype=object)

# %%
#Change male leaning
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['m'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['M'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Let\'s keep it simple and say "male"'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Masculine'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cishet male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Man'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['cis male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Trans Man'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['I have a penis'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['man'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['masculino'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['CIS Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cis Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cis Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Cis Male'],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Male '],'Male')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Trans man'],'Male')
# Out:
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Change female leaning
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['f'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['F'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Female-identified'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Agender trans woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Female (cis)'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Femile'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['femmina'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['female'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['cis woman'],'Female')
MentalHealthClean2['Sex'] = MentalHealthClean2['Sex'].replace(['Female '],'Female')
# Out:
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\jocel\.conda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
MentalHealthClean2['Sex'].unique()
# Out:
# array(['Male', 'Female', nan, 'Non-binary', 'Identify as male',
#        'Non binary', 'None', 'Nonbinary', 'agender', 'Questioning', 'rr',
#        '43', 'I am a Wookie', 'Make', 'Trans non-binary/genderfluid',
#        'Non-binary and gender fluid'], dtype=object)

# %%
# Number by gender
MentalHealthClean2['Sex']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 347      Male
# 348      Male
# 349      Male
# 350    Female
# 351    Female
# Name: Sex, Length: 352, dtype: object

# %%
#Dropping other labels 
L= ['Non-binary', 'Non binary', 'None',
       'Nonbinary', 'agender', 'Questioning', 'rr', '43', 'I am a Wookie',
       'Make', 'Trans non-binary/genderfluid',
       'Non-binary and gender fluid']

print (MentalHealthClean2[~MentalHealthClean2.Sex.isin(L)])
MentalHealthClean2
# Out:
#      Age     Sex   Location Emp. Coverage  Ranking  \
# 0     25    Male   Nebraska  I don't know        4
# 1     51    Male   Nebraska           Yes        1
# 2     27    Male   Illinois  I don't know        2
# 3     37    Male   Nebraska  I don't know        3
# 4     46    Male   Nebraska  I don't know        3
# ..   ...     ...        ...           ...      ...
# 347   27    Male        NaN  I don't know        3
# 348   48    Male  Louisiana           NaN        3
# 349   50    Male        NaN           NaN        5
# 350   30  Female        NaN            No        2
# 351   24  Female     Oregon           Yes        3
#
#     Do you *currently* have a mental health disorder?
# 0                                          Don't Know
# 1                                            Possibly
# 2                                                  No
# 3                                                  No
# 4                                                  No
# ..                                                ...
# 347                                          Possibly
# 348                                                No
# 349                                                No
# 350                                          Possibly
# 351                                               Yes
#
# [337 rows x 6 columns]
#      Age     Sex   Location Emp. Coverage  Ranking  \
# 0     25    Male   Nebraska  I don't know        4
# 1     51    Male   Nebraska           Yes        1
# 2     27    Male   Illinois  I don't know        2
# 3     37    Male   Nebraska  I don't know        3
# 4     46    Male   Nebraska  I don't know        3
# ..   ...     ...        ...           ...      ...
# 347   27    Male        NaN  I don't know        3
# 348   48    Male  Louisiana           NaN        3
# 349   50    Male        NaN           NaN        5
# 350   30  Female        NaN            No        2
# 351   24  Female     Oregon           Yes        3
#
#     Do you *currently* have a mental health disorder?
# 0                                          Don't Know
# 1                                            Possibly
# 2                                                  No
# 3                                                  No
# 4                                                  No
# ..                                                ...
# 347                                          Possibly
# 348                                                No
# 349                                                No
# 350                                          Possibly
# 351                                               Yes
#
# [352 rows x 6 columns]

# %%
output_data_file = "MentalH.csv"

# %%
#MentalHealthClean2.to_csv(index=False)

# %%
MH_Clean['Do you *currently* have a mental health disorder?'].unique()
# Out:
# array(["Don't Know", 'Possibly', 'No', 'Yes'], dtype=object)

# %%
#Dropping other labels 
L= ["Don't Know", 'Possibly']


print (MentalHealthClean2[~MentalHealthClean2."Do you *currently* have a mental health disorder?".isin(L)])
MentalHealthClean2
# Out:
#   File "<ipython-input-226-7e4af903ef01>", line 5
#     print (MentalHealthClean2[~MentalHealthClean2."Do you *currently* have a mental health disorder?".isin(L)])
#                                                                                                     ^
# SyntaxError: invalid syntax
