# %%
import pandas as pd
import csv
import json
import pymongo
from pymongo import MongoClient

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
ETL_db=mydb.db

# %%
collection=ETL_db.collection

# %%
csv_male=pd.read_csv("/Users/heatherallardice/Desktop/Male.csv")
csv_male.reset_index(drop=True, inplace=False)
csv_male
# Out:
#      Sex              Location  Bad Days count  Bad Days mean  Bad Days min  \
# 0   Male               Alabama               1            4.6           4.6
# 1   Male                Alaska               1            3.3           3.3
# 2   Male               Arizona               1            4.1           4.1
# 3   Male              Arkansas               1            4.2           4.2
# 4   Male            California               1            3.4           3.4
# 5   Male              Colorado               1            3.6           3.6
# 6   Male           Connecticut               1            3.4           3.4
# 7   Male              Delaware               1            3.6           3.6
# 8   Male  District of Columbia               1            3.5           3.5
# 9   Male               Florida               1            3.7           3.7
# 10  Male               Georgia               1            4.3           4.3
# ...

# %%
 # create a dictionary 
    data = {} 
      
    # Open a csv reader called DictReader 
    with open("/Users/heatherallardice/Desktop/Male.csv", encoding='utf-8') as csvf: 
        csvReader = csv.DictReader(csvf) 
          
        # Convert each row into a dictionary  
        # and add it to data 
        for rows in csvReader: 
              
            # Assuming a column named 'No' to 
            # be the primary key 
            key = rows['Location'] 
            data[key] = rows

# %%
data
# Out:
# {'Alabama': OrderedDict([('Sex', 'Male'),
#               ('Location', 'Alabama'),
#               ('Bad Days count', '1'),
#               ('Bad Days mean', '4.6'),
#               ('Bad Days min', '4.6'),
#               ('Bad Days Q1', '4.6'),
#               ('Bad Days Q2 ', '4.6'),
#               ('Bad Days Q3 ', '4.6'),
#               ('Bad Days max', '4.6')]),
#  'Alaska': OrderedDict([('Sex', 'Male'),
#               ('Location', 'Alaska'),
#               ('Bad Days count', '1'),
#               ('Bad Days mean', '3.3'),
#               ('Bad Days min', '3.3'),
#               ('Bad Days Q1', '3.3'),
#               ('Bad Days Q2 ', '3.3'),
#               ('Bad Days Q3 ', '3.3'),
#               ('Bad Days max', '3.3')]),
#  'Arizona': OrderedDict([('Sex', 'Male'),
#               ('Location', 'Arizona'),
#               ('Bad Days count', '1'),
#               ('Bad Days mean', '4.1'),
#               ('Bad Days min', '4.1'),
#               ('Bad Days Q1', '4.1'),
# ...

# %%
# Open a json writer, and use the json.dumps()  
# function to dump data 
jsonFilePath = r'Names.json'
with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonf.write(json.dumps(data, indent=4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-1f60557b8fa5> in <module>
#       3 jsonFilePath = r'Names.json'
#       4 with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
# ----> 5         jsonf.write(json.dumps(data, indent=4))
#       6
#
# ~/opt/anaconda3/envs/Pythondata/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# ~/opt/anaconda3/envs/Pythondata/lib/python3.6/json/encoder.py in encode(self, o)
#     199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
# ...

# %%
data= collection.insert_one(data)

# %%
myCursor = ETL_db.collection.find( {'Bad Days mean': "4.6" } )
myCursor
