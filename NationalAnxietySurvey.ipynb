# %%
import os
from bs4 import BeautifulSoup as bs
import requests
import pymongo
from splinter import Browser
import pandas as pd
import time

# %%
# Make a reference to thecsv file path
csv_path = "NationalAnxietySurvey.csv"

# Import the books.csv file as a DataFrame
NAS_df = pd.read_csv(csv_path)
NAS_df.head()
# Out:
#     id   age sex literacy  martialstatus recentbravement employementstatus  \
# 0  1.0  35.0   f         y             y               n                 y
# 1  2.0  45.0   m         y             y               y                 y
# 2  3.0  35.0   m         y             y               n                 y
# 3  4.0  56.0   m         y             y               n                 y
# 4  5.0  45.0   m         y             y               n                 y
#
#    socialeconomicstatus(0-5) familyhistory anyaddiction anychronicdesease  \
# 0                          2             y            n                 n
# 1                          5             n            y                 n
# 2                          0             n            n                 y
# 3                          1             n            n                 n
# 4                          0             y            n                 n
#
#    feel
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
NAS_df.columns.values
# Out:
# array(['id', 'age', 'sex', 'literacy ', 'martialstatus',
#        'recentbravement', 'employementstatus',
#        'socialeconomicstatus(0-5)', 'familyhistory', 'anyaddiction',
#        'anychronicdesease', 'feel'], dtype=object)

# %%
NAS_df_c = NAS_df.drop(columns=['feel', 'martialstatus'])
NAS_df_c
# Out:
#        id   age  sex literacy  recentbravement employementstatus  \
# 0     1.0  35.0    f         y               n                 y
# 1     2.0  45.0    m         y               y                 y
# 2     3.0  35.0    m         y               n                 y
# 3     4.0  56.0    m         y               n                 y
# 4     5.0  45.0    m         y               n                 y
# ...   ...   ...  ...       ...             ...               ...
# 1967  NaN   NaN  NaN       NaN             NaN               NaN
# 1968  NaN   NaN  NaN       NaN             NaN               NaN
# 1969  NaN   NaN  NaN       NaN             NaN               NaN
# 1970  NaN   NaN  NaN       NaN             NaN               NaN
# 1971  NaN   NaN  NaN       NaN             NaN               NaN
#
#       socialeconomicstatus(0-5) familyhistory anyaddiction anychronicdesease
# 0                             2             y            n                 n
# 1                             5             n            y                 n
# 2                             0             n            n                 y
# 3                             1             n            n                 n
# 4                             0             y            n                 n
# ...                         ...           ...          ...               ...
# 1967                          5           NaN          NaN               NaN
# 1968                          1           NaN          NaN               NaN
# 1969                          4           NaN          NaN               NaN
# 1970                          2           NaN          NaN               NaN
# 1971                          4           NaN          NaN               NaN
#
# [1972 rows x 10 columns]

# %%
NAS_df_c.dropna(how='all')
# Out:
#        id   age  sex literacy  recentbravement employementstatus  \
# 0     1.0  35.0    f         y               n                 y
# 1     2.0  45.0    m         y               y                 y
# 2     3.0  35.0    m         y               n                 y
# 3     4.0  56.0    m         y               n                 y
# 4     5.0  45.0    m         y               n                 y
# ...   ...   ...  ...       ...             ...               ...
# 1967  NaN   NaN  NaN       NaN             NaN               NaN
# 1968  NaN   NaN  NaN       NaN             NaN               NaN
# 1969  NaN   NaN  NaN       NaN             NaN               NaN
# 1970  NaN   NaN  NaN       NaN             NaN               NaN
# 1971  NaN   NaN  NaN       NaN             NaN               NaN
#
#       socialeconomicstatus(0-5) familyhistory anyaddiction anychronicdesease
# 0                             2             y            n                 n
# 1                             5             n            y                 n
# 2                             0             n            n                 y
# 3                             1             n            n                 n
# 4                             0             y            n                 n
# ...                         ...           ...          ...               ...
# 1967                          5           NaN          NaN               NaN
# 1968                          1           NaN          NaN               NaN
# 1969                          4           NaN          NaN               NaN
# 1970                          2           NaN          NaN               NaN
# 1971                          4           NaN          NaN               NaN
#
# [1972 rows x 10 columns]

# %%
#NAS_df_c = NAS_df_c.apply (pd.to_numeric, errors='coerce')
NAS_df_c = NAS_df_c.dropna(['id'] == True )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-6c0f77672a4b> in <module>
#       1 #NAS_df_c = NAS_df_c.apply (pd.to_numeric, errors='coerce')
# ----> 2 NAS_df_c = NAS_df_c.dropna(['id'] == True )
#
# AttributeError: 'function' object has no attribute 'dropna'
