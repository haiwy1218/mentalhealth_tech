# %%
#import Dependencies
import csv
import json
import pandas as pd
import sys, getopt, pprint
from pymongo import MongoClient
import warnings
warnings.filterwarnings('ignore')

# %%
#activating Mongo Client
client = MongoClient('localhost', 27017)

# %%
db = client.db

# %%
collection= db.collection

# %%
#creating the Data Frame Female and reading the csv
Female=pd.read_csv(r'C:\Users\pasi1\mentalhealth_tech\Female.csv', index_col=0)

# %%
#print Female
print(Female)
# Out:
#                   Unnamed: 1 Bad Days Bad Days.1 Bad Days.2 Bad Days.3  \
# Sex                 Location    count       mean        std        min
# Female               Alabama        1        6.1        NaN        6.1
# Female                Alaska        1        4.6        NaN        4.6
# Female               Arizona        1        4.9        NaN        4.9
# Female              Arkansas        1        6.5        NaN        6.5
# Female            California        1        4.2        NaN        4.2
# Female              Colorado        1        4.4        NaN        4.4
# Female           Connecticut        1        4.2        NaN        4.2
# Female              Delaware        1          5        NaN          5
# Female  District of Columbia        1        4.8        NaN        4.8
# Female               Florida        1          5        NaN          5
# Female               Georgia        1        5.2        NaN        5.2
# ...

# %%
#turning it into a dictionary
def csv_to_dict():
    reader = csv.DictReader(open(''/'Female.csv'))
    result = {}
    for row in reader:
        key = row.pop('Sex')
        result[key] = row
    return query

# %%
# create a dictionary 
    Female = {} 
      
    # Open a csv reader called DictReader 
    with open(r'C:\Users\pasi1\mentalhealth_tech\Female.csv', encoding='utf-8') as csvf: 
        csvReader = csv.DictReader(csvf) 
          
        # Convert each row into a dictionary  
        # and add it to data 
        for rows in csvReader: 
              
            # Assuming a column named 'No' to 
            # be the primary key 
            key = rows[''] 
            Female[key] = rows

# %%
#printing dictionary
Female
# Out:
# {'Location': OrderedDict([('', 'Location'), ('Bad Days', 'max')]),
#  'Alabama': OrderedDict([('', 'Alabama'), ('Bad Days', '6.1')]),
#  'Alaska': OrderedDict([('', 'Alaska'), ('Bad Days', '4.6')]),
#  'Arizona': OrderedDict([('', 'Arizona'), ('Bad Days', '4.9')]),
#  'Arkansas': OrderedDict([('', 'Arkansas'), ('Bad Days', '6.5')]),
#  'California': OrderedDict([('', 'California'), ('Bad Days', '4.2')]),
#  'Colorado': OrderedDict([('', 'Colorado'), ('Bad Days', '4.4')]),
#  'Connecticut': OrderedDict([('', 'Connecticut'), ('Bad Days', '4.2')]),
#  'Delaware': OrderedDict([('', 'Delaware'), ('Bad Days', '5')]),
#  'District of Columbia': OrderedDict([('', 'District of Columbia'),
#               ('Bad Days', '4.8')]),
#  'Florida': OrderedDict([('', 'Florida'), ('Bad Days', '5')]),
#  'Georgia': OrderedDict([('', 'Georgia'), ('Bad Days', '5.2')]),
#  'Guam': OrderedDict([('', 'Guam'), ('Bad Days', '4.8')]),
#  'Hawaii': OrderedDict([('', 'Hawaii'), ('Bad Days', '3.8')]),
# ...

# %%
# Opening csv file
with open('Female.csv', 'r') as csvfile:
    header = [ "show_id", "Sex"]
    reader = csv.reader(csvfile)

    for row in reader:
        doc={}
        for n in range(0,len(header)):
            doc[header[n]] = row[n]

# %%
#importing CSV
def import_content(filepath):
    collection_name = 'Female' 
    db_cm = mng_db[collection_name]
    cdir = os.path.dirname(__file__)
    file_res = os.path.join(cdir, filepath)

    data = pd.read_csv(file_res)
    data_json = json.loads(data.to_json(orient='Sex'))
    db_cm.remove()
    db_cm.insert(data_json)
    filepath = ''/'Female.csv'  
    import_content(filepath)

# %%
#count of female
Female.count()
# Out:
# Unnamed: 1    54
# Bad Days      54
# Bad Days.1    54
# Bad Days.2     1
# Bad Days.3    54
# Bad Days.4    54
# Bad Days.5    54
# Bad Days.6    54
# Bad Days.7    54
# dtype: int64

# %%
#first 5 in in DataFrame
Female.head()
# Out:
#        Unnamed: 1 Bad Days Bad Days.1 Bad Days.2 Bad Days.3 Bad Days.4  \
# Sex      Location    count       mean        std        min        25%
# Female    Alabama        1        6.1        NaN        6.1        6.1
# Female     Alaska        1        4.6        NaN        4.6        4.6
# Female    Arizona        1        4.9        NaN        4.9        4.9
# Female   Arkansas        1        6.5        NaN        6.5        6.5
#
#        Bad Days.5 Bad Days.6 Bad Days.7
# Sex           50%        75%        max
# Female        6.1        6.1        6.1
# Female        4.6        4.6        4.6
# Female        4.9        4.9        4.9
# Female        6.5        6.5        6.5

# %%
# Getting shape of the df 
shape = Female.shape 
  
# Printing Number of columns 
print('Number of columns :', shape[1])
# Out:
# Number of columns : 9

# %%
# Getting the list of columns 
col = Female.columns 
  
# Printing Number of columns 
print('Number of columns :', len(col))
# Out:
# Number of columns : 9

# %%
#inforamtion about the DataFrame
Female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, Sex to Female
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 1  54 non-null     object
#  1   Bad Days    54 non-null     object
#  2   Bad Days.1  54 non-null     object
#  3   Bad Days.2  1 non-null      object
#  4   Bad Days.3  54 non-null     object
#  5   Bad Days.4  54 non-null     object
#  6   Bad Days.5  54 non-null     object
#  7   Bad Days.6  54 non-null     object
#  8   Bad Days.7  54 non-null     object
# dtypes: object(9)
# memory usage: 4.2+ KB

# %%
# grouping by hte count of Unnamed one which is Location
Female.groupby(['Unnamed: 1']).count().unstack().fillna(0)
# Out:
#             Unnamed: 1
# Bad Days    Alabama          1
#             Alaska           1
#             Arizona          1
#             Arkansas         1
#             California       1
#                             ..
# Bad Days.7  Virginia         1
#             Washington       1
#             West Virginia    1
#             Wisconsin        1
#             Wyoming          1
# Length: 432, dtype: int64

# %%
#importing Dependencies for SQL
from numpy import genfromtxt
from time import time
from datetime import datetime
from sqlalchemy import Column, Integer, Float, Date
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.automap import automap_base

# %%
#Connecting to postgrsql server
engine = create_engine('postgresql://pasi1215@localhost:27017/mydatabase')

# %%
factory = sessionmaker(bind=engine)
session = factory()
for instance in session.query(Female).filter_by(FirstName="Unnamed:1"):
    print("Unnamed:1", instance.State)
print("Bad Days: 1", instance.mean)
print("---------")
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-20-36174f3432cc> in <module>
#       1 factory = sessionmaker(bind=engine)
#       2 session = factory()
# ----> 3 for instance in session.query(Female).filter_by(FirstName="Unnamed:1"):
#       4     print("Unnamed:1", instance.State)
#       5 print("Bad Days: 1", instance.mean)
#
# ~\OneDrive\Documents\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py in query(self, *entities, **kwargs)
#    1582         :class:`.Session`."""
#    1583
# -> 1584         return self._query_cls(entities, self, **kwargs)
#    1585
#    1586     @property
#
# ~\OneDrive\Documents\envs\PythonData\lib\site-packages\sqlalchemy\orm\query.py in __init__(self, entities, session)
#     197         self.session = session
#     198         self._polymorphic_adapters = {}
# --> 199         self._set_entities(entities)
#     200
# ...

# %%
metadata = db.MetaData()
Sex = db.Table('Unnamed:1', metadata, autoload=True, autoload_with=engine)

# %%
print(Sex.columns.keys())

# %%
print(repr(metadata.tables['Sex']))
