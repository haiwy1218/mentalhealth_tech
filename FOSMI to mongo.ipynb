# %%
import pandas as pd
import csv
import json
import pymongo
from pymongo import MongoClient

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.db
collection = db.collection

# %%
#Split or re import to get rid of ''''''
csv_fosmi=pd.read_csv("fosmi.csv")
csv_fosmi.reset_index(drop=True, inplace=False)
csv_fosmi
# Out:
#     """Age     Sex      Location Emp. Coverage  Ranking  \
# 0    """36  Female      Nebraska           Yes        3
# 1    """39  Female      Nebraska           Yes        3
# 2    """26  Female  Pennsylvania           Yes        3
# 3    """32  Female      New York           Yes        3
# 4    """40  Female      New York           Yes        4
# ..     ...     ...           ...           ...      ...
# 96   """42  Female         Texas           Yes        3
# 97   """26  Female           NaN           Yes        2
# 98   """31  Female    California            No        3
# 99   """30  Female           NaN            No        2
# 100  """24  Female        Oregon           Yes        3
#
#     Do you *currently* have a mental health disorder?"""
# 0                                               Yes"""
# 1                                               Yes"""
# 2                                               Yes"""
# 3                                          Possibly"""
# ...

# %%
#read csv
fosmi_db = pd.read_csv(r'fosmi.csv')

print(male_db)
# Out:
#     """Age     Sex      Location Emp. Coverage  Ranking  \
# 0    """36  Female      Nebraska           Yes        3
# 1    """39  Female      Nebraska           Yes        3
# 2    """26  Female  Pennsylvania           Yes        3
# 3    """32  Female      New York           Yes        3
# 4    """40  Female      New York           Yes        4
# ..     ...     ...           ...           ...      ...
# 96   """42  Female         Texas           Yes        3
# 97   """26  Female           NaN           Yes        2
# 98   """31  Female    California            No        3
# 99   """30  Female           NaN            No        2
# 100  """24  Female        Oregon           Yes        3
#
#     Do you *currently* have a mental health disorder?"""
# 0                                               Yes"""
# 1                                               Yes"""
# 2                                               Yes"""
# 3                                          Possibly"""
# ...

# %%
#Make into blank dictionary
result = {}
#get csv reader
def csv_to_dict():
    reader = csv.DictReader(open(''/'fosmi.csv'))
   
    for row in reader:
        key = row['Sex']
        result[key] = row

# %%
result
# Out:
# {}

# %%
#print dict
print(csv_to_dict)
# Out:
# <function csv_to_dict at 0x0000021B4D903950>

# %%
#open csv


with open('fosmi.csv', 'r') as csvfile:
    header = [ "show_id", "Sex"]
    reader = csv.reader(csvfile)

    for row in reader:
        doc={}
        for n in range(0,len(header)):
            doc[header[n]] = row[n]

# %%
#Import CSV

def content(filepath):
    collection_name = 'db.collection' 
    db_cm = mng_db[collection_name]
    cdir = os.path.dirname(__file__)
    file_res = os.path.join(cdir, filepath)

    data = pd.read_csv(file_res)
    data_json = json.loads(data.to_json(orient='Sex'))
    db_cm.remove()
    db_cm.insert(data_json)
    filepath = ''/'fosmi.csv'  
    import_content(filepath)
